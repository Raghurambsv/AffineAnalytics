# %% [markdown]
# # Model Inference Code

# %% [markdown]
# <b> Table of Contents</b>
# - Imports
# - Loading model into memory
# - Inference on all the images and summary generation

# %% [markdown]
# ## Checking the installation of Tensorflow Object detection API

# %%
# !ls
# Out:
# area_report_after_inference_08052020.csv
# confidence_report_after_inference_08052020.csv
# count_report_after_inference_08052020.csv
# eval_val_exp1_iter8
# fine_tuned_model_exp1_iter3_25000
# fine_tuned_model_iter_15000
# frozen_inference_graph_18895_cutoff0.5
# frozen_inference_graph_18895.pb
# frozen_inference_graph_20000_cutoff0.5
# frozen_inference_graph_20000.pb
# frozen_inference_graph_iter1_step13871.pb
# frozen_inference_graph_iter1_step17815.pb
# frozen_inference_graph_iter2_step19714.pb
# frozen_inference_graph_iter3_step23740.pb
# frozen_inference_graph_iter3_step25000.pb
# frozen_inference_graph_iter3_step27829.pb
# frozen_inference_graph_iter4_step20812.pb
# frozen_inference_graph_iter5_step28000.pb
# frozen_inference_graph_iter8_step30000.pb
# frozen_inference_graph.pb
# home
# iter3_step25000
# iter4_step20812
# iter5_step28000
# iter7_20000
# iter8_step30000
# iter9_step15000
# known
# Object_Detection_Inference_SSD_v5.1.2-Copy1.ipynb
# Object_Detection_Inference_SSD_v5.1.2.ipynb
# Object_Detection_Inference_SSD_v5.1.3.ipynb
# object-detection.pbtxt
# ssd_inception_v2_coco.config
# ssd_inception_v2_cocov2.config
# test_combined
# thu_cutoff0.5
# train
# training
# training_exp1iter2_2.zip
# training_exp1_iter3
# unknown
# valid
# val.record

# %%
# %cd /home/ubuntu/models/research
# Out:
# /home/ubuntu/models/research

# %%
# !echo $PYTHONPATH
# Out:
# :/home/ubuntu/models/research:/home/ubuntu/models/research/slim

# %%
# !python object_detection/builders/model_builder_test.py
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# Running tests under Python 3.6.10: /home/ubuntu/.conda/envs/dristi2/bin/python
# [ RUN      ] ModelBuilderTest.test_create_experimental_model
# [       OK ] ModelBuilderTest.test_create_experimental_model
# [ RUN      ] ModelBuilderTest.test_create_faster_rcnn_model_from_config_with_example_miner
# [       OK ] ModelBuilderTest.test_create_faster_rcnn_model_from_config_with_example_miner
# [ RUN      ] ModelBuilderTest.test_create_faster_rcnn_models_from_config_faster_rcnn_with_matmul
# [       OK ] ModelBuilderTest.test_create_faster_rcnn_models_from_config_faster_rcnn_with_matmul
# [ RUN      ] ModelBuilderTest.test_create_faster_rcnn_models_from_config_faster_rcnn_without_matmul
# [       OK ] ModelBuilderTest.test_create_faster_rcnn_models_from_config_faster_rcnn_without_matmul
# [ RUN      ] ModelBuilderTest.test_create_faster_rcnn_models_from_config_mask_rcnn_with_matmul
# [       OK ] ModelBuilderTest.test_create_faster_rcnn_models_from_config_mask_rcnn_with_matmul
# [ RUN      ] ModelBuilderTest.test_create_faster_rcnn_models_from_config_mask_rcnn_without_matmul
# [       OK ] ModelBuilderTest.test_create_faster_rcnn_models_from_config_mask_rcnn_without_matmul
# [ RUN      ] ModelBuilderTest.test_create_rfcn_model_from_config
# [       OK ] ModelBuilderTest.test_create_rfcn_model_from_config
# [ RUN      ] ModelBuilderTest.test_create_ssd_fpn_model_from_config
# [       OK ] ModelBuilderTest.test_create_ssd_fpn_model_from_config
# [ RUN      ] ModelBuilderTest.test_create_ssd_models_from_config
# [       OK ] ModelBuilderTest.test_create_ssd_models_from_config
# [ RUN      ] ModelBuilderTest.test_invalid_faster_rcnn_batchnorm_update
# [       OK ] ModelBuilderTest.test_invalid_faster_rcnn_batchnorm_update
# [ RUN      ] ModelBuilderTest.test_invalid_first_stage_nms_iou_threshold
# [       OK ] ModelBuilderTest.test_invalid_first_stage_nms_iou_threshold
# [ RUN      ] ModelBuilderTest.test_invalid_model_config_proto
# [       OK ] ModelBuilderTest.test_invalid_model_config_proto
# [ RUN      ] ModelBuilderTest.test_invalid_second_stage_batch_size
# [       OK ] ModelBuilderTest.test_invalid_second_stage_batch_size
# [ RUN      ] ModelBuilderTest.test_session
# [  SKIPPED ] ModelBuilderTest.test_session
# [ RUN      ] ModelBuilderTest.test_unknown_faster_rcnn_feature_extractor
# [       OK ] ModelBuilderTest.test_unknown_faster_rcnn_feature_extractor
# [ RUN      ] ModelBuilderTest.test_unknown_meta_architecture
# [       OK ] ModelBuilderTest.test_unknown_meta_architecture
# [ RUN      ] ModelBuilderTest.test_unknown_ssd_feature_extractor
# [       OK ] ModelBuilderTest.test_unknown_ssd_feature_extractor
# ----------------------------------------------------------------------
# Ran 17 tests in 0.223s
#
# OK (skipped=1)

# %%
#------main part of code

# %% [markdown]
# ## Imports

# %%
# importing library
import numpy as np
import os
import six.moves.urllib as urllib
import sys
import tarfile
import tensorflow as tf
import zipfile
from collections import defaultdict
from io import StringIO
from matplotlib import pyplot as plt
from PIL import Image
import time
import csv
import pandas as pd
import pathlib
from keras.preprocessing.image import ImageDataGenerator
from keras import backend as K
import math
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Environment Setup

# %%
# This is needed to display the images.
# %matplotlib inline

# %% [markdown]
# ## Object detection imports
# Here are the imports from the object detection module.

# %%
from object_detection.utils import label_map_util
from object_detection.utils import visualization_utils as vis_util

# %% [markdown]
# Patches:

# %%
if tf.__version__.startswith('2.'):
  # patch tf1 into `utils.ops`
  utils_ops.tf = tf.compat.v1

  # Patch the location of gfile
  tf.gfile = tf.io.gfile

# %% [markdown]
# ## Configurations and file paths

# %%
# Mention the name of the model .pb and the labels .pbtxt file
# Path to frozen detection graph. This is the actual model that is used for the object detection.
frozen_model_fname = '/home/ubuntu/dristi_ssd_model/frozen_inference_graph_20000.pb'

# List of the strings that is used to add correct label for each box.
label_map_pbtxt_fname = '/home/ubuntu/dristi_ssd_model/object-detection.pbtxt' # labels file path

# Number of classes
NUM_CLASSES = 5

# Path to the test images folder for inference - set the zip folder path if zip folder is uploaded
test_img_folder_path = '/home/ubuntu/dristi_ssd_model/test_combined'

# Size, in inches, of the output images.
IMAGE_SIZE = (24, 24)

# Path to the binary classifiaction model file
model_path = "/home/ubuntu/dristi/resnet50_Png_full_data_acc_split.model"

# Threshold for binary classifcation
threshold = 0.5

# Threshold for object detection
cutoff = 0.4
# cutoff = 1e-8

# IoU threshold for non-max suppression
iou_threshold=0.1

# List of defect - in the order of annotation
defect_cols = ['Mistracking','Trim','Contamination','Tear','Wrinkle/Fold']

# Image size for binary classification
img_rows, img_cols = 512,512

# %% [markdown]
# ## Model preparation
# ### Variables
# Any model exported using the export_inference_graph.py tool can be loaded here

# %%
# # Extracting the tar model file - incase we upload a tar model folder - run when upload a new tar folder
# tar = tarfile.open("/home/ubuntu/dristi/fine_tuned_modelv_with_dist_color_finetuned19713.tar.gz")
# tar.extractall()
# tar.close()

# %%
# Checking the folder contents - QC step (whether the frozen graph is present or not)
# !ls fine_tuned_modelv_with_dist_color_finetuned19713

# %%
# Displaying the present worrking directory - should be research folder
# !pwd
# Out:
# /home/ubuntu/models/research

# %% [markdown]
# ### Load a (frozen) Tensorflow model into memory

# %%
# %%time
def load_model(frozen_model_fname):
    detection_graph = tf.Graph()
    with detection_graph.as_default():
        od_graph_def = tf.GraphDef()
        with tf.gfile.GFile(frozen_model_fname, 'rb') as fid:
            serialized_graph = fid.read()
            od_graph_def.ParseFromString(serialized_graph)
            tf.import_graph_def(od_graph_def, name='')
    return detection_graph
detection_graph = load_model(frozen_model_fname)
# Out:
# CPU times: user 528 ms, sys: 176 ms, total: 704 ms
# Wall time: 705 ms

# %% [markdown]
# ### Loading the binary classification model into memory

# %%
#Initializing own performance metric

def f1(y_true, y_pred):
    def recall(y_true, y_pred):
        """Recall metric.

        Only computes a batch-wise average of recall.

        Computes the recall, a metric for multi-label classification of
        how many relevant items are selected.
        """
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
        recall = true_positives / (possible_positives + K.epsilon())
        return recall

    def precision(y_true, y_pred):
        """Precision metric.

        Only computes a batch-wise average of precision.

        Computes the precision, a metric for multi-label classification of
        how many selected items are relevant.
        """
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
        precision = true_positives / (predicted_positives + K.epsilon())
        return precision
    precision = precision(y_true, y_pred)
    recall = recall(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))

# %%
# Loading the binary classification model into memory
from keras.models import load_model
st = time.time()
model = load_model(model_path, custom_objects={'f1': f1})
print("time taken", time.time()-st)
# Out:
# WARNING:tensorflow:From /home/ubuntu/.conda/envs/dristi2/lib/python3.6/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /home/ubuntu/.conda/envs/dristi2/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /home/ubuntu/.conda/envs/dristi2/lib/python3.6/site-packages/tensorflow_core/python/ops/nn_impl.py:183: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /home/ubuntu/.conda/envs/dristi2/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# time taken 18.157276153564453

# %% [markdown]
# ### Loading label map
# Label maps map indices to category names, so that when our convolution network predicts 1, we know that this corresponds to Mistracking and when it predicts 2, we know it corresponds to Trim, and so on. Here we use internal utility functions, but anything that returns a dictionary mapping integers to appropriate string labels would be fine.

# %%
label_map = label_map_util.load_labelmap(label_map_pbtxt_fname)
categories = label_map_util.convert_label_map_to_categories(label_map, max_num_classes=NUM_CLASSES, use_display_name=True)
category_index = label_map_util.create_category_index(categories)

# %% [markdown]
# ### Helper code

# %%
# Since we need our images in a specific format - since 3 channel image is accepted
def load_image_into_numpy_array(image):
    # The function supports only grayscale images
    last_axis = -1
    dim_to_repeat = 2
    repeats = 3
    grscale_img_3dims = np.expand_dims(image, last_axis)
    training_image = np.repeat(grscale_img_3dims, repeats, dim_to_repeat).astype('uint8')
    assert len(training_image.shape) == 3
    assert training_image.shape[-1] == 3
    return training_image

# %%
# #use this function when you have ground truth boxes
# def load_image_into_numpy_array(image):
#     (im_width, im_height) = image.size
#     return np.array(image.getdata()).reshape(
#         (im_height, im_width, 3)).astype(np.uint8)

# %% [markdown]
# ## Detection in images
# ### Reading the various files and folders

# %%
# Unzip the folder - uncomment when uploading new images in zip folder
#  !unzip {test_img_folder_path}
#  Setting the foldername now as the path as the folder gets unzipped in the pwd
#  test_img_folder_path = test_img_folder_path.split('/')[-1].split('.')[0]

# %%
# If you want to test the code with your images, just add path to the images to the TEST_IMAGE_PATHS.
PATH_TO_TEST_IMAGES_DIR = pathlib.Path(test_img_folder_path)
TEST_IMAGE_PATHS = sorted(list(PATH_TO_TEST_IMAGES_DIR.glob("*.jpg")))
TEST_IMAGE_PATHS
# Out:
# [PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20191207_050605_819_3.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20191208_123531_849_3.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20191208_172306_479_1.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20191210_174100_732_3.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20191210_211959_279_3.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20191211_132955_017_3.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20191211_143347_920_3.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20191213_101200_470_3.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20191216_182320_254_3.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20191217_041555_632_3.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20191217_232357_580_3.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20191217_232358_403_3.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20191218_063541_647_3.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20191218_143415_554_1.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20191219_003928_420_1.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20191220_042651_317_1.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20191220_124936_956_3.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20191220_124936_990_1.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20191220_130027_734_3.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20191221_010621_953_1.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20191223_205617_570_1.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20191227_155935_012_1.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20191227_221546_811_3.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20191228_034119_396_1.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20191228_041021_793_1.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20191228_042800_300_1.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20191228_042800_471_1.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20191228_042801_637_3.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20191228_042802_906_1.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20191228_042803_934_3.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20191228_042807_020_1.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20191228_042807_603_3.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20191228_042808_974_1.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20191228_042809_797_3.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20191228_060136_467_1.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20191228_060136_501_1.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20191228_164850_508_1.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20191228_173632_539_1.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20191228_175924_722_3.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20191228_185450_044_1.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20191229_023954_493_1.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20191229_035147_225_1.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20191229_173903_007_1.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20191230_000134_717_3.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20191230_000134_751_1.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20191230_121051_025_3.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200102_091703_089_3.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200102_125707_720_1.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200103_020704_783_1.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200103_214230_302_3.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200103_230658_841_1.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200104_121634_506_1.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200105_043239_471_3.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200105_181955_501_3.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200105_193430_066_1.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200105_224319_288_1.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200105_224319_329_1.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200106_050655_815_3.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200109_181104_516_3.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200109_181104_653_3.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200109_181105_545_3.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200110_093015_482_3.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200111_060841_426_3.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200112_150847_871_3.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200113_150544_490_3.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200116_091406_585_3.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200122_175238_690_3.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200123_043313_774_3.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200123_044506_032_3.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200123_104748_813_3.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200123_112350_837_3.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200123_114151_645_3.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200123_121644_307_3.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200123_125343_279_3.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200123_132847_496_3.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200123_132947_702_3.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200123_134650_411_3.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200123_140452_982_3.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200123_140553_188_3.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200123_144741_485_3.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200123_151254_391_3.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200123_153156_449_3.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200123_160112_323_3.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200123_162701_962_3.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200123_170203_916_3.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200130_014820_216_3.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200130_020807_599_3.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200130_083746_102_3.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200130_084718_708_3.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200130_112126_731_3.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200130_112530_742_3.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200130_145112_676_3.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200130_160700_196_3.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200130_161140_859_3.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200130_163417_957_3.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200130_164210_345_3.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200130_173030_162_3.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200130_173046_311_3.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200130_190442_437_3.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200130_201552_296_3.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200212_205039_164_3.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200217_075143_396_3.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200301_101713_822_3.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200301_115324_189_3.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200301_115324_226_3.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200304_040913_807_3.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200305_012324_171_1.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200305_012324_206_1.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200306_001055_740_3.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200306_023946_655_1.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200306_152410_725_1.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200306_213322_098_3.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200308_054726_920_3.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200308_185647_494_1.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200313_053509_033_3.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200314_160532_748_3.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200322_234714_586_3.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200323_083553_911_3.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200328_154348_207_3.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200328_163559_144_3.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200328_173803_953_3.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200328_180937_107_3.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200328_182033_816_3.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200328_182200_593_3.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200328_204206_109_3.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200328_205140_841_3.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200328_215931_173_3.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200329_132507_714_3.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200405_230301_559_3.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200408_055536_503_1.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200410_074306_096_1.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200410_074309_422_1.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200410_183210_387_1.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200410_183927_564_1.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200410_202938_703_3.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200411_044813_755_3.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200411_113231_131_1.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200411_113231_165_1.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200411_130808_778_1.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200411_140300_807_1.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200411_160158_699_1.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200411_173555_065_1.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200412_044117_268_1.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200412_144224_254_1.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200414_103254_585_1.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200414_230853_425_1.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200415_150359_849_1.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200415_150359_952_1.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200416_020241_609_1.jpg'),
#  PosixPath('/home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200416_024506_582_3.jpg')]

# %% [markdown]
# ## This section is used to get the inference on the images
# - First, it classifies the images into good or bad
# - Then, for the bad images only we do the inference
# - The defect is identified as well as localised
# - In case, there are no known defects identified in the defected images, we mark it as an unknown defect
# - In case of good(no defect) images it is just marked as good

# %% [markdown]
# ### Binary classification inference

# %%
# This function takes in an image and infers it to have defect/no defect(good)
def binary_classification_inference(threshold,TEST_IMAGE_PATHS,model):
    from keras.preprocessing import image
    start = time.time()   
    def add_prediction(image_path):
        st_bc = time.time()
        image_key = str(image_path).split('/')[-1].split('.')[0]
        img = image.load_img(image_path, target_size = (img_rows, img_cols))
        img = image.img_to_array(img)
        img = np.expand_dims(img, axis = 0)
        img /= 255
        prob = model.predict(img)[0][0]
        print("Time taken for binary classification inference of 1 image",time.time() - st_bc)
        return (image_key,prob,int(prob<threshold))
    predictions = [add_prediction(image_path) for image_path in TEST_IMAGE_PATHS]
    predicted_label_df = pd.DataFrame(predictions,columns = ['Image_Name','Probability','Predicted_Class'])
    print(predicted_label_df)
    end = time.time()
    print("Time taken for binary classification inference of all images",end - start)
    return predicted_label_df.set_index("Image_Name")

# %% [markdown]
# ### Object detection inference - including binary classifaction

# %%
# %%time
# %matplotlib inline
def get_inference(predicted_label_df,TEST_IMAGE_PATHS,cutoff):
    from collections import defaultdict
    start = time.time()
    with detection_graph.as_default():
        with tf.Session(graph=detection_graph) as sess:
            # Definite input and output Tensors for detection_graph
            image_tensor = detection_graph.get_tensor_by_name('image_tensor:0')
            # Each box represents a part of the image where a particular object was detected.
            detection_boxes = detection_graph.get_tensor_by_name('detection_boxes:0')
            # Each score represent how level of confidence for each of the objects.
            # Score is shown on the result image, together with the class label.
            detection_scores = detection_graph.get_tensor_by_name('detection_scores:0')
            detection_classes = detection_graph.get_tensor_by_name('detection_classes:0')
            num_detections = detection_graph.get_tensor_by_name('num_detections:0')
            image_summary = pd.DataFrame(columns=['Image_key']+defect_cols+['Unknown','Good'])
            
            total_count = 0
            for image_path in TEST_IMAGE_PATHS:
                print(image_path)
                st_od = time.time()
                image_key = str(image_path).split('/')[-1].split('.')[0]
                # Loading for classification task
                image = Image.open(image_path)
                # the array based representation of the image will be used later in order to prepare the
                # result image with boxes and labels on it.
                image_np = load_image_into_numpy_array(image)
                original_img = image_np.copy()
                # Expand dimensions since the model expects images to have shape: [1, None, None, 3]
                image_np_expanded = np.expand_dims(image_np, axis=0)
                
                if predicted_label_df.at[image_key,"Predicted_Class"] == 1:
                    # Actual detection.
                    (boxes, scores, classes, num) = sess.run(
                        [detection_boxes, detection_scores, detection_classes, num_detections],
                        feed_dict={image_tensor: image_np_expanded})
                    selected_indices = tf.image.non_max_suppression(
                                        boxes[0], scores[0], num[0], iou_threshold=iou_threshold,score_threshold=cutoff)
                    selected_boxes = tf.gather(boxes[0], selected_indices).eval()
                    selected_classes = tf.gather(classes[0], selected_indices).eval()
                    selected_scores = tf.gather(scores[0], selected_indices).eval()
                    
                    predicted_classes = list(selected_classes.astype(np.int32))
                    conf_scores = list(selected_scores)
                    print(list(zip(predicted_classes,conf_scores)))
                    if predicted_classes:
                        # Visualization of the results of a detection.
                        vis_util.visualize_boxes_and_labels_on_image_array(
                            image_np,
                            selected_boxes,
                            selected_classes.astype(np.int32),
                            selected_scores,
                            category_index,
                            use_normalized_coordinates=True,
                            line_thickness=8,
                            min_score_thresh=cutoff)
                        suffix = '_'.join(list(set([defect_cols[i-1].replace('/','_') for i in predicted_classes])))
                        if not os.path.exists('/home/ubuntu/dristi_ssd_model/iter7_20000/nms_cutoff0.4/test/known/'):
                            os.makedirs('/home/ubuntu/dristi_ssd_model/iter7_20000/nms_cutoff0.4/test/known/')
                        plt.imsave('/home/ubuntu/dristi_ssd_model/iter7_20000/nms_cutoff0.4/test/known/'+image_path.stem+'_'+suffix+'.jpg', image_np)
                        row = {"Image_key":image_key+'-'+suffix}
                        d = defaultdict(list)
                        [d[x[0]].append(x[1]) for x in zip([defect_cols[i-1] for i in predicted_classes],\
                                                           conf_scores)]
                        row.update(d)
                        image_summary = image_summary.append(row, ignore_index=True)
                    else:
                        print("unknown defect")
                        suffix = 'Unknown'
                        if not os.path.exists('/home/ubuntu/dristi_ssd_model/iter7_20000/nms_cutoff0.4/test/unknown/'):
                            os.makedirs('/home/ubuntu/dristi_ssd_model/iter7_20000/nms_cutoff0.4/test/unknown/')
                        plt.imsave('/home/ubuntu/dristi_ssd_model/iter7_20000/nms_cutoff0.4/test/unknown/'+image_path.stem+'_'+suffix+'.jpg', image_np)
                        row = {"Image_key":image_key+'-'+suffix}
                        d = defaultdict(list)
                        d['Unknown'].append(1-predicted_label_df.at[image_key,"Probability"])
                        row.update(d)
                        image_summary = image_summary.append(row, ignore_index=True)
#                     fig = plt.figure(figsize=IMAGE_SIZE)
#                     fig.add_subplot(1, 2, 1)
#                     plt.imshow(original_img)
#                     fig.add_subplot(1, 2, 2)
#                     plt.imshow(image_np)
#                     plt.show()
                    print("Time taken for object detection inference", time.time() - st_od)
                else:
                    print("no defect")
                    if not os.path.exists('/home/ubuntu/dristi_ssd_model/iter7_20000/nms_cutoff0.4/test/good/'):
                        os.makedirs('/home/ubuntu/dristi_ssd_model/iter7_20000/nms_cutoff0.4/test/good/')
                    suffix = 'Good'
                    plt.imsave('/home/ubuntu/dristi_ssd_model/iter7_20000/nms_cutoff0.4/test/good/'+image_path.stem+'_'+suffix+'.jpg', image_np)
                    row = {"Image_key":image_key+'-'+suffix}
                    d = defaultdict(list)
                    d['Good'].append(predicted_label_df.at[image_key,"Probability"])
                    row.update(d)
                    image_summary = image_summary.append(row, ignore_index=True)
                total_count+=1
            print("Defect Summary")
            def get_defect_conf_per_image(x):
                try:
                    l = np.mean(x)
                except:
                    l = None
                return l
            report1 = image_summary.set_index("Image_key")[defect_cols+['Unknown','Good']]\
                                    .applymap(get_defect_conf_per_image)
            print(report1)
            print("overall summary")
            overall_summary = pd.DataFrame(image_summary[defect_cols+['Unknown','Good']].count()\
                                           .append(pd.Series({'total':total_count})),columns = ['count'])
            overall_summary['Percentage'] = (overall_summary['count']*100)/total_count
            print(overall_summary)
            end = time.time()
            print("Time taken for overall object detection inference for all images",end - start)
            def get_defect_count_per_image(x):
                try:
                    l = len(x)
                except:
                    l = 0
                return l
            report2 = image_summary.set_index("Image_key")[defect_cols+['Unknown','Good']]\
                                    .applymap(get_defect_count_per_image)
            report2.to_csv("/home/ubuntu/dristi_ssd_model/iter7_20000/nms_cutoff0.4/test/report2_after_inference2.csv")

            
start_overall = time.time()
get_inference(binary_classification_inference(threshold,TEST_IMAGE_PATHS,model),TEST_IMAGE_PATHS,cutoff)
print("Total time taken for all images for complete inference",time.time()-start_overall)
# Out:
# Time taken for binary classification inference of 1 image 1.8561558723449707
# Time taken for binary classification inference of 1 image 0.48079490661621094
# Time taken for binary classification inference of 1 image 0.4716796875
# Time taken for binary classification inference of 1 image 0.4804375171661377
# Time taken for binary classification inference of 1 image 0.48114657402038574
# Time taken for binary classification inference of 1 image 0.4770019054412842
# Time taken for binary classification inference of 1 image 0.47886085510253906
# Time taken for binary classification inference of 1 image 0.4809749126434326
# Time taken for binary classification inference of 1 image 0.482637882232666
# Time taken for binary classification inference of 1 image 0.4803035259246826
# Time taken for binary classification inference of 1 image 0.47882843017578125
# Time taken for binary classification inference of 1 image 0.47451186180114746
# Time taken for binary classification inference of 1 image 0.48197031021118164
# Time taken for binary classification inference of 1 image 0.476132869720459
# Time taken for binary classification inference of 1 image 0.4776127338409424
# Time taken for binary classification inference of 1 image 0.474581241607666
# Time taken for binary classification inference of 1 image 0.4808518886566162
# Time taken for binary classification inference of 1 image 0.4761214256286621
# Time taken for binary classification inference of 1 image 0.4815335273742676
# Time taken for binary classification inference of 1 image 0.4778878688812256
# Time taken for binary classification inference of 1 image 0.47881293296813965
# Time taken for binary classification inference of 1 image 0.480945348739624
# Time taken for binary classification inference of 1 image 0.48051929473876953
# Time taken for binary classification inference of 1 image 0.4811699390411377
# Time taken for binary classification inference of 1 image 0.4806501865386963
# Time taken for binary classification inference of 1 image 0.47867369651794434
# Time taken for binary classification inference of 1 image 0.4701857566833496
# Time taken for binary classification inference of 1 image 0.4800271987915039
# Time taken for binary classification inference of 1 image 0.47771716117858887
# Time taken for binary classification inference of 1 image 0.48361706733703613
# Time taken for binary classification inference of 1 image 0.48139524459838867
# Time taken for binary classification inference of 1 image 0.48352479934692383
# Time taken for binary classification inference of 1 image 0.482602596282959
# Time taken for binary classification inference of 1 image 0.4805135726928711
# Time taken for binary classification inference of 1 image 0.46935439109802246
# Time taken for binary classification inference of 1 image 0.4726274013519287
# Time taken for binary classification inference of 1 image 0.4696011543273926
# Time taken for binary classification inference of 1 image 0.4838259220123291
# Time taken for binary classification inference of 1 image 0.4713575839996338
# Time taken for binary classification inference of 1 image 0.4755568504333496
# Time taken for binary classification inference of 1 image 0.4702489376068115
# Time taken for binary classification inference of 1 image 0.4840540885925293
# Time taken for binary classification inference of 1 image 0.4726707935333252
# Time taken for binary classification inference of 1 image 0.47563886642456055
# Time taken for binary classification inference of 1 image 0.4789919853210449
# Time taken for binary classification inference of 1 image 0.4805312156677246
# Time taken for binary classification inference of 1 image 0.4787890911102295
# Time taken for binary classification inference of 1 image 0.47209954261779785
# Time taken for binary classification inference of 1 image 0.4693629741668701
# Time taken for binary classification inference of 1 image 0.471881628036499
# Time taken for binary classification inference of 1 image 0.48151135444641113
# Time taken for binary classification inference of 1 image 0.4818840026855469
# Time taken for binary classification inference of 1 image 0.47434067726135254
# Time taken for binary classification inference of 1 image 0.47685742378234863
# Time taken for binary classification inference of 1 image 0.4759814739227295
# Time taken for binary classification inference of 1 image 0.47544169425964355
# Time taken for binary classification inference of 1 image 0.478790283203125
# Time taken for binary classification inference of 1 image 0.4726254940032959
# Time taken for binary classification inference of 1 image 0.471041202545166
# Time taken for binary classification inference of 1 image 0.48415660858154297
# Time taken for binary classification inference of 1 image 0.4746541976928711
# Time taken for binary classification inference of 1 image 0.47283935546875
# Time taken for binary classification inference of 1 image 0.4760317802429199
# Time taken for binary classification inference of 1 image 0.479511022567749
# Time taken for binary classification inference of 1 image 0.482607364654541
# Time taken for binary classification inference of 1 image 0.4773557186126709
# Time taken for binary classification inference of 1 image 0.47689342498779297
# Time taken for binary classification inference of 1 image 0.483806848526001
# Time taken for binary classification inference of 1 image 0.4756953716278076
# Time taken for binary classification inference of 1 image 0.4778478145599365
# Time taken for binary classification inference of 1 image 0.4760293960571289
# Time taken for binary classification inference of 1 image 0.48251819610595703
# Time taken for binary classification inference of 1 image 0.4786374568939209
# Time taken for binary classification inference of 1 image 0.4714531898498535
# Time taken for binary classification inference of 1 image 0.4749472141265869
# Time taken for binary classification inference of 1 image 0.4780149459838867
# Time taken for binary classification inference of 1 image 0.48419713973999023
# Time taken for binary classification inference of 1 image 0.4789726734161377
# Time taken for binary classification inference of 1 image 0.47365379333496094
# Time taken for binary classification inference of 1 image 0.4784064292907715
# Time taken for binary classification inference of 1 image 0.4758172035217285
# Time taken for binary classification inference of 1 image 0.4813845157623291
# Time taken for binary classification inference of 1 image 0.4830501079559326
# Time taken for binary classification inference of 1 image 0.4695699214935303
# Time taken for binary classification inference of 1 image 0.47989368438720703
# Time taken for binary classification inference of 1 image 0.4771244525909424
# Time taken for binary classification inference of 1 image 0.4727311134338379
# Time taken for binary classification inference of 1 image 0.48679423332214355
# Time taken for binary classification inference of 1 image 0.48127007484436035
# Time taken for binary classification inference of 1 image 0.4709963798522949
# Time taken for binary classification inference of 1 image 0.48020434379577637
# Time taken for binary classification inference of 1 image 0.47902464866638184
# Time taken for binary classification inference of 1 image 0.4714081287384033
# Time taken for binary classification inference of 1 image 0.4835045337677002
# Time taken for binary classification inference of 1 image 0.4830176830291748
# Time taken for binary classification inference of 1 image 0.4711120128631592
# Time taken for binary classification inference of 1 image 0.4745490550994873
# Time taken for binary classification inference of 1 image 0.4745981693267822
# Time taken for binary classification inference of 1 image 0.48068761825561523
# Time taken for binary classification inference of 1 image 0.474484920501709
# Time taken for binary classification inference of 1 image 0.4766981601715088
# Time taken for binary classification inference of 1 image 0.4733438491821289
# Time taken for binary classification inference of 1 image 0.47998523712158203
# Time taken for binary classification inference of 1 image 0.48447227478027344
# Time taken for binary classification inference of 1 image 0.478452205657959
# Time taken for binary classification inference of 1 image 0.4721212387084961
# Time taken for binary classification inference of 1 image 0.4787271022796631
# Time taken for binary classification inference of 1 image 0.48308658599853516
# Time taken for binary classification inference of 1 image 0.4736976623535156
# Time taken for binary classification inference of 1 image 0.47952961921691895
# Time taken for binary classification inference of 1 image 0.479245662689209
# Time taken for binary classification inference of 1 image 0.48206591606140137
# Time taken for binary classification inference of 1 image 0.48144960403442383
# Time taken for binary classification inference of 1 image 0.4848160743713379
# Time taken for binary classification inference of 1 image 0.477785587310791
# Time taken for binary classification inference of 1 image 0.4693727493286133
# Time taken for binary classification inference of 1 image 0.46901702880859375
# Time taken for binary classification inference of 1 image 0.47612667083740234
# Time taken for binary classification inference of 1 image 0.47615981101989746
# Time taken for binary classification inference of 1 image 0.4789285659790039
# Time taken for binary classification inference of 1 image 0.481626033782959
# Time taken for binary classification inference of 1 image 0.48177599906921387
# Time taken for binary classification inference of 1 image 0.4769613742828369
# Time taken for binary classification inference of 1 image 0.48029494285583496
# Time taken for binary classification inference of 1 image 0.4817078113555908
# Time taken for binary classification inference of 1 image 0.478179931640625
# Time taken for binary classification inference of 1 image 0.47672533988952637
# Time taken for binary classification inference of 1 image 0.4818580150604248
# Time taken for binary classification inference of 1 image 0.47938108444213867
# Time taken for binary classification inference of 1 image 0.4719505310058594
# Time taken for binary classification inference of 1 image 0.47731542587280273
# Time taken for binary classification inference of 1 image 0.47589850425720215
# Time taken for binary classification inference of 1 image 0.4692697525024414
# Time taken for binary classification inference of 1 image 0.4716949462890625
# Time taken for binary classification inference of 1 image 0.4790666103363037
# Time taken for binary classification inference of 1 image 0.4809098243713379
# Time taken for binary classification inference of 1 image 0.4791419506072998
# Time taken for binary classification inference of 1 image 0.4776444435119629
# Time taken for binary classification inference of 1 image 0.46956443786621094
# Time taken for binary classification inference of 1 image 0.47170138359069824
# Time taken for binary classification inference of 1 image 0.48066186904907227
# Time taken for binary classification inference of 1 image 0.47267937660217285
# Time taken for binary classification inference of 1 image 0.47153282165527344
# Time taken for binary classification inference of 1 image 0.47864580154418945
# Time taken for binary classification inference of 1 image 0.478893518447876
# Time taken for binary classification inference of 1 image 0.48268604278564453
# Time taken for binary classification inference of 1 image 0.47339367866516113
# Time taken for binary classification inference of 1 image 0.4791421890258789
# Time taken for binary classification inference of 1 image 0.4783589839935303
# Time taken for binary classification inference of 1 image 0.4843571186065674
#                            Image_Name   Probability  Predicted_Class
# 0    VISUCI1_S1_20191207_050605_819_3  0.000000e+00                1
# 1    VISUCI1_S1_20191208_123531_849_3  0.000000e+00                1
# 2    VISUCI1_S1_20191208_172306_479_1  1.319113e-07                1
# 3    VISUCI1_S1_20191210_174100_732_3  0.000000e+00                1
# 4    VISUCI1_S1_20191210_211959_279_3  0.000000e+00                1
# ..                                ...           ...              ...
# 145  VISUCI1_S1_20200414_230853_425_1  0.000000e+00                1
# 146  VISUCI1_S1_20200415_150359_849_1  0.000000e+00                1
# 147  VISUCI1_S1_20200415_150359_952_1  0.000000e+00                1
# 148  VISUCI1_S1_20200416_020241_609_1  6.015605e-07                1
# 149  VISUCI1_S1_20200416_024506_582_3  4.155515e-08                1
#
# [150 rows x 3 columns]
# Time taken for binary classification inference of all images 73.06423354148865
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20191207_050605_819_3.jpg
# []
# unknown defect
# Time taken for object detection inference 1.0941040515899658
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20191208_123531_849_3.jpg
# []
# unknown defect
# Time taken for object detection inference 0.3779315948486328
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20191208_172306_479_1.jpg
# []
# unknown defect
# Time taken for object detection inference 0.3802034854888916
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20191210_174100_732_3.jpg
# [(1, 0.8905314)]
# Time taken for object detection inference 0.38503336906433105
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20191210_211959_279_3.jpg
# [(5, 0.49889135)]
# Time taken for object detection inference 0.3888998031616211
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20191211_132955_017_3.jpg
# []
# unknown defect
# Time taken for object detection inference 0.3865931034088135
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20191211_143347_920_3.jpg
# [(3, 0.98407364)]
# Time taken for object detection inference 0.3951282501220703
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20191213_101200_470_3.jpg
# [(5, 0.54413074)]
# Time taken for object detection inference 0.3894331455230713
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20191216_182320_254_3.jpg
# []
# unknown defect
# Time taken for object detection inference 0.38806867599487305
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20191217_041555_632_3.jpg
# []
# unknown defect
# Time taken for object detection inference 0.3887293338775635
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20191217_232357_580_3.jpg
# []
# unknown defect
# Time taken for object detection inference 0.39023804664611816
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20191217_232358_403_3.jpg
# []
# unknown defect
# Time taken for object detection inference 0.39539241790771484
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20191218_063541_647_3.jpg
# []
# unknown defect
# Time taken for object detection inference 0.39400720596313477
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20191218_143415_554_1.jpg
# [(2, 0.9629051), (1, 0.67976093), (4, 0.42437547)]
# Time taken for object detection inference 0.4102768898010254
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20191219_003928_420_1.jpg
# [(2, 0.997915), (2, 0.7638051), (4, 0.57840145)]
# Time taken for object detection inference 0.407423734664917
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20191220_042651_317_1.jpg
# [(2, 0.99591553), (2, 0.99113977), (1, 0.9723339), (4, 0.5370019)]
# Time taken for object detection inference 0.4133584499359131
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20191220_124936_956_3.jpg
# []
# unknown defect
# Time taken for object detection inference 0.3982551097869873
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20191220_124936_990_1.jpg
# []
# unknown defect
# Time taken for object detection inference 0.4003255367279053
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20191220_130027_734_3.jpg
# []
# unknown defect
# Time taken for object detection inference 0.40406274795532227
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20191221_010621_953_1.jpg
# [(1, 0.976385), (1, 0.74667346)]
# Time taken for object detection inference 0.4240410327911377
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20191223_205617_570_1.jpg
# [(2, 0.5732863)]
# Time taken for object detection inference 0.4087033271789551
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20191227_155935_012_1.jpg
# [(2, 0.96416867), (1, 0.46857333)]
# Time taken for object detection inference 0.4140510559082031
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20191227_221546_811_3.jpg
# []
# unknown defect
# Time taken for object detection inference 0.4124155044555664
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20191228_034119_396_1.jpg
# [(5, 0.84530413)]
# Time taken for object detection inference 0.41559529304504395
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20191228_041021_793_1.jpg
# [(1, 0.64049214), (1, 0.52694947)]
# Time taken for object detection inference 0.4251682758331299
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20191228_042800_300_1.jpg
# [(5, 0.40510094)]
# Time taken for object detection inference 0.42400574684143066
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20191228_042800_471_1.jpg
# [(4, 0.5479232)]
# Time taken for object detection inference 0.42224717140197754
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20191228_042801_637_3.jpg
# [(4, 0.69818866)]
# Time taken for object detection inference 0.42241382598876953
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20191228_042802_906_1.jpg
# [(5, 0.77040017), (5, 0.41119182)]
# Time taken for object detection inference 0.42896318435668945
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20191228_042803_934_3.jpg
# [(5, 0.7071084)]
# Time taken for object detection inference 0.4262731075286865
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20191228_042807_020_1.jpg
# []
# unknown defect
# Time taken for object detection inference 0.43051648139953613
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20191228_042807_603_3.jpg
# [(5, 0.5925757), (4, 0.547872)]
# Time taken for object detection inference 0.44115781784057617
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20191228_042808_974_1.jpg
# [(5, 0.49780965)]
# Time taken for object detection inference 0.4392828941345215
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20191228_042809_797_3.jpg
# [(4, 0.6997669)]
# Time taken for object detection inference 0.43222594261169434
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20191228_060136_467_1.jpg
# []
# unknown defect
# Time taken for object detection inference 0.42687296867370605
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20191228_060136_501_1.jpg
# [(1, 0.5137693)]
# Time taken for object detection inference 0.4385261535644531
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20191228_164850_508_1.jpg
# [(1, 0.9120667), (2, 0.7840408), (4, 0.6415315)]
# Time taken for object detection inference 0.44182658195495605
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20191228_173632_539_1.jpg
# no defect
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20191228_175924_722_3.jpg
# [(4, 0.9742094)]
# Time taken for object detection inference 0.43527674674987793
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20191228_185450_044_1.jpg
# []
# unknown defect
# Time taken for object detection inference 0.4327571392059326
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20191229_023954_493_1.jpg
# [(1, 0.8295503), (2, 0.7915883)]
# Time taken for object detection inference 0.45392680168151855
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20191229_035147_225_1.jpg
# [(2, 0.8486718), (5, 0.46782163)]
# Time taken for object detection inference 0.44217753410339355
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20191229_173903_007_1.jpg
# [(2, 0.9988053), (2, 0.98191357)]
# Time taken for object detection inference 0.4509773254394531
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20191230_000134_717_3.jpg
# [(4, 0.9818119), (4, 0.96128106), (1, 0.43969703)]
# Time taken for object detection inference 0.44773268699645996
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20191230_000134_751_1.jpg
# []
# unknown defect
# Time taken for object detection inference 0.4362504482269287
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20191230_121051_025_3.jpg
# []
# unknown defect
# Time taken for object detection inference 0.4421813488006592
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200102_091703_089_3.jpg
# [(3, 0.9951576), (1, 0.9188999)]
# Time taken for object detection inference 0.4479188919067383
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200102_125707_720_1.jpg
# [(5, 0.6211633), (2, 0.6137812)]
# Time taken for object detection inference 0.45236921310424805
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200103_020704_783_1.jpg
# []
# unknown defect
# Time taken for object detection inference 0.44593334197998047
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200103_214230_302_3.jpg
# [(4, 0.97984827)]
# Time taken for object detection inference 0.4581124782562256
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200103_230658_841_1.jpg
# []
# unknown defect
# Time taken for object detection inference 0.44651126861572266
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200104_121634_506_1.jpg
# [(1, 0.94316113), (1, 0.81023335)]
# Time taken for object detection inference 0.47036314010620117
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200105_043239_471_3.jpg
# [(3, 0.9946997)]
# Time taken for object detection inference 0.4724619388580322
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200105_181955_501_3.jpg
# []
# unknown defect
# Time taken for object detection inference 0.4615752696990967
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200105_193430_066_1.jpg
# [(5, 0.93946975)]
# Time taken for object detection inference 0.45450305938720703
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200105_224319_288_1.jpg
# []
# unknown defect
# Time taken for object detection inference 0.45148587226867676
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200105_224319_329_1.jpg
# []
# unknown defect
# Time taken for object detection inference 0.4536576271057129
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200106_050655_815_3.jpg
# [(3, 0.996549)]
# Time taken for object detection inference 0.46817898750305176
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200109_181104_516_3.jpg
# [(3, 0.8238706), (1, 0.78134876)]
# Time taken for object detection inference 0.4749410152435303
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200109_181104_653_3.jpg
# [(3, 0.9890785), (1, 0.8227694)]
# Time taken for object detection inference 0.4695155620574951
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200109_181105_545_3.jpg
# [(3, 0.9553838), (1, 0.8297069)]
# Time taken for object detection inference 0.46364641189575195
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200110_093015_482_3.jpg
# []
# unknown defect
# Time taken for object detection inference 0.45810413360595703
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200111_060841_426_3.jpg
# [(1, 0.97265124), (4, 0.8634434)]
# Time taken for object detection inference 0.4704935550689697
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200112_150847_871_3.jpg
# [(1, 0.5264653)]
# Time taken for object detection inference 0.4631199836730957
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200113_150544_490_3.jpg
# [(1, 0.69535375)]
# Time taken for object detection inference 0.4689147472381592
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200116_091406_585_3.jpg
# [(3, 0.9900483), (1, 0.9751034)]
# Time taken for object detection inference 0.4688096046447754
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200122_175238_690_3.jpg
# [(4, 0.9259705), (5, 0.73262674), (4, 0.6992709)]
# Time taken for object detection inference 0.48169803619384766
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200123_043313_774_3.jpg
# []
# unknown defect
# Time taken for object detection inference 0.46367359161376953
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200123_044506_032_3.jpg
# [(4, 0.9235846)]
# Time taken for object detection inference 0.4743533134460449
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200123_104748_813_3.jpg
# [(1, 0.7436908)]
# Time taken for object detection inference 0.4742767810821533
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200123_112350_837_3.jpg
# []
# unknown defect
# Time taken for object detection inference 0.47081828117370605
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200123_114151_645_3.jpg
# [(1, 0.5638348)]
# Time taken for object detection inference 0.4739701747894287
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200123_121644_307_3.jpg
# []
# unknown defect
# Time taken for object detection inference 0.47394633293151855
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200123_125343_279_3.jpg
# []
# unknown defect
# Time taken for object detection inference 0.4753715991973877
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200123_132847_496_3.jpg
# []
# unknown defect
# Time taken for object detection inference 0.4740254878997803
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200123_132947_702_3.jpg
# []
# unknown defect
# Time taken for object detection inference 0.47953033447265625
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200123_134650_411_3.jpg
# []
# unknown defect
# Time taken for object detection inference 0.4765968322753906
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200123_140452_982_3.jpg
# []
# unknown defect
# Time taken for object detection inference 0.48107147216796875
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200123_140553_188_3.jpg
# []
# unknown defect
# Time taken for object detection inference 0.48022937774658203
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200123_144741_485_3.jpg
# []
# unknown defect
# Time taken for object detection inference 0.4883108139038086
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200123_151254_391_3.jpg
# []
# unknown defect
# Time taken for object detection inference 0.4895493984222412
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200123_153156_449_3.jpg
# []
# unknown defect
# Time taken for object detection inference 0.4862821102142334
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200123_160112_323_3.jpg
# [(1, 0.4242268)]
# Time taken for object detection inference 0.4880959987640381
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200123_162701_962_3.jpg
# []
# unknown defect
# Time taken for object detection inference 0.48738765716552734
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200123_170203_916_3.jpg
# []
# unknown defect
# Time taken for object detection inference 0.48637843132019043
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200130_014820_216_3.jpg
# []
# unknown defect
# Time taken for object detection inference 0.49492692947387695
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200130_020807_599_3.jpg
# []
# unknown defect
# Time taken for object detection inference 0.4945030212402344
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200130_083746_102_3.jpg
# []
# unknown defect
# Time taken for object detection inference 0.5010666847229004
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200130_084718_708_3.jpg
# [(3, 0.98844755)]
# Time taken for object detection inference 0.5021300315856934
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200130_112126_731_3.jpg
# [(3, 0.9115546)]
# Time taken for object detection inference 0.5046813488006592
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200130_112530_742_3.jpg
# [(3, 0.42044348)]
# Time taken for object detection inference 0.5028865337371826
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200130_145112_676_3.jpg
# []
# unknown defect
# Time taken for object detection inference 0.5057070255279541
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200130_160700_196_3.jpg
# [(3, 0.9312447)]
# Time taken for object detection inference 0.5053086280822754
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200130_161140_859_3.jpg
# [(3, 0.4468002)]
# Time taken for object detection inference 0.5119185447692871
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200130_163417_957_3.jpg
# [(3, 0.96736944)]
# Time taken for object detection inference 0.5118083953857422
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200130_164210_345_3.jpg
# [(3, 0.7752789)]
# Time taken for object detection inference 0.5239448547363281
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200130_173030_162_3.jpg
# [(3, 0.6005836)]
# Time taken for object detection inference 0.5104453563690186
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200130_173046_311_3.jpg
# [(3, 0.9733285), (3, 0.41504177)]
# Time taken for object detection inference 0.5201597213745117
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200130_190442_437_3.jpg
# [(3, 0.99338055)]
# Time taken for object detection inference 0.514662504196167
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200130_201552_296_3.jpg
# [(3, 0.9421156)]
# Time taken for object detection inference 0.5189790725708008
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200212_205039_164_3.jpg
# []
# unknown defect
# Time taken for object detection inference 0.509498119354248
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200217_075143_396_3.jpg
# []
# unknown defect
# Time taken for object detection inference 0.5194339752197266
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200301_101713_822_3.jpg
# []
# unknown defect
# Time taken for object detection inference 0.5203070640563965
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200301_115324_189_3.jpg
# []
# unknown defect
# Time taken for object detection inference 0.5176079273223877
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200301_115324_226_3.jpg
# []
# unknown defect
# Time taken for object detection inference 0.5161864757537842
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200304_040913_807_3.jpg
# []
# unknown defect
# Time taken for object detection inference 0.5167145729064941
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200305_012324_171_1.jpg
# [(5, 0.6775554)]
# Time taken for object detection inference 0.5239784717559814
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200305_012324_206_1.jpg
# [(1, 0.68318915)]
# Time taken for object detection inference 0.527090311050415
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200306_001055_740_3.jpg
# [(1, 0.5549022)]
# Time taken for object detection inference 0.5271012783050537
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200306_023946_655_1.jpg
# []
# unknown defect
# Time taken for object detection inference 0.5279452800750732
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200306_152410_725_1.jpg
# [(4, 0.99977064), (4, 0.9446641)]
# Time taken for object detection inference 0.5351643562316895
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200306_213322_098_3.jpg
# []
# unknown defect
# Time taken for object detection inference 0.5229928493499756
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200308_054726_920_3.jpg
# []
# unknown defect
# Time taken for object detection inference 0.5304737091064453
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200308_185647_494_1.jpg
# [(1, 0.68431336), (5, 0.5118741)]
# Time taken for object detection inference 0.5348894596099854
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200313_053509_033_3.jpg
# []
# unknown defect
# Time taken for object detection inference 0.5338592529296875
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200314_160532_748_3.jpg
# [(3, 0.5337771), (1, 0.47024086)]
# Time taken for object detection inference 0.5384576320648193
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200322_234714_586_3.jpg
# []
# unknown defect
# Time taken for object detection inference 0.5349276065826416
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200323_083553_911_3.jpg
# [(1, 0.8056379)]
# Time taken for object detection inference 0.535874605178833
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200328_154348_207_3.jpg
# [(1, 0.81082904), (3, 0.447825)]
# Time taken for object detection inference 0.5469162464141846
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200328_163559_144_3.jpg
# [(3, 0.9679861)]
# Time taken for object detection inference 0.5412557125091553
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200328_173803_953_3.jpg
# []
# unknown defect
# Time taken for object detection inference 0.5364847183227539
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200328_180937_107_3.jpg
# [(1, 0.854127), (3, 0.60981)]
# Time taken for object detection inference 0.5522496700286865
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200328_182033_816_3.jpg
# []
# unknown defect
# Time taken for object detection inference 0.548907995223999
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200328_182200_593_3.jpg
# [(3, 0.8463563)]
# Time taken for object detection inference 0.5509130954742432
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200328_204206_109_3.jpg
# [(3, 0.76642597)]
# Time taken for object detection inference 0.5540714263916016
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200328_205140_841_3.jpg
# [(3, 0.99585986)]
# Time taken for object detection inference 0.5535240173339844
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200328_215931_173_3.jpg
# [(3, 0.95962846), (3, 0.9535489)]
# Time taken for object detection inference 0.5539016723632812
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200329_132507_714_3.jpg
# [(3, 0.67228717)]
# Time taken for object detection inference 0.5605745315551758
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200405_230301_559_3.jpg
# []
# unknown defect
# Time taken for object detection inference 0.5473928451538086
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200408_055536_503_1.jpg
# []
# unknown defect
# Time taken for object detection inference 0.5498390197753906
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200410_074306_096_1.jpg
# []
# unknown defect
# Time taken for object detection inference 0.5511476993560791
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200410_074309_422_1.jpg
# [(5, 0.5792536)]
# Time taken for object detection inference 0.5705797672271729
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200410_183210_387_1.jpg
# [(1, 0.96876717)]
# Time taken for object detection inference 0.5624284744262695
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200410_183927_564_1.jpg
# [(2, 0.99662185)]
# Time taken for object detection inference 0.5579562187194824
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200410_202938_703_3.jpg
# [(1, 0.9251934)]
# Time taken for object detection inference 0.5610237121582031
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200411_044813_755_3.jpg
# [(3, 0.6385204)]
# Time taken for object detection inference 0.5606529712677002
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200411_113231_131_1.jpg
# []
# unknown defect
# Time taken for object detection inference 0.5631778240203857
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200411_113231_165_1.jpg
# []
# unknown defect
# Time taken for object detection inference 0.561180591583252
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200411_130808_778_1.jpg
# [(2, 0.9186404)]
# Time taken for object detection inference 0.5628798007965088
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200411_140300_807_1.jpg
# [(5, 0.59370875)]
# Time taken for object detection inference 0.5687541961669922
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200411_160158_699_1.jpg
# [(2, 0.9705602)]
# Time taken for object detection inference 0.5654006004333496
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200411_173555_065_1.jpg
# [(1, 0.98276234), (1, 0.6471245), (1, 0.5650308)]
# Time taken for object detection inference 0.5864977836608887
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200412_044117_268_1.jpg
# [(2, 0.9889955), (2, 0.9862238), (5, 0.49984547)]
# Time taken for object detection inference 0.5823161602020264
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200412_144224_254_1.jpg
# [(4, 0.8690048)]
# Time taken for object detection inference 0.5779330730438232
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200414_103254_585_1.jpg
# []
# unknown defect
# Time taken for object detection inference 0.5696492195129395
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200414_230853_425_1.jpg
# [(2, 0.99194735), (1, 0.6905613)]
# Time taken for object detection inference 0.5772113800048828
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200415_150359_849_1.jpg
# [(4, 0.9824492), (4, 0.57119465)]
# Time taken for object detection inference 0.5813624858856201
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200415_150359_952_1.jpg
# [(4, 0.9991994), (4, 0.99559176)]
# Time taken for object detection inference 0.5781476497650146
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200416_020241_609_1.jpg
# [(2, 0.95034045), (1, 0.8635705)]
# Time taken for object detection inference 0.5852372646331787
# /home/ubuntu/dristi_ssd_model/test_combined/VISUCI1_S1_20200416_024506_582_3.jpg
# [(1, 0.97153056), (5, 0.9185175), (3, 0.6836556)]
# Time taken for object detection inference 0.5883698463439941
# Defect Summary
#                                                     Mistracking      Trim  \
# Image_key
# VISUCI1_S1_20191207_050605_819_3-Unknown                    NaN       NaN
# VISUCI1_S1_20191208_123531_849_3-Unknown                    NaN       NaN
# VISUCI1_S1_20191208_172306_479_1-Unknown                    NaN       NaN
# VISUCI1_S1_20191210_174100_732_3-Mistracking           0.890531       NaN
# VISUCI1_S1_20191210_211959_279_3-Wrinkle_Fold               NaN       NaN
# ...                                                         ...       ...
# VISUCI1_S1_20200414_230853_425_1-Mistracking_Trim      0.690561  0.991947
# VISUCI1_S1_20200415_150359_849_1-Tear                       NaN       NaN
# VISUCI1_S1_20200415_150359_952_1-Tear                       NaN       NaN
# VISUCI1_S1_20200416_020241_609_1-Mistracking_Trim      0.863571  0.950340
# VISUCI1_S1_20200416_024506_582_3-Wrinkle_Fold_M...     0.971531       NaN
#
#                                                     Contamination      Tear  \
# Image_key
# VISUCI1_S1_20191207_050605_819_3-Unknown                      NaN       NaN
# VISUCI1_S1_20191208_123531_849_3-Unknown                      NaN       NaN
# VISUCI1_S1_20191208_172306_479_1-Unknown                      NaN       NaN
# VISUCI1_S1_20191210_174100_732_3-Mistracking                  NaN       NaN
# VISUCI1_S1_20191210_211959_279_3-Wrinkle_Fold                 NaN       NaN
# ...                                                           ...       ...
# VISUCI1_S1_20200414_230853_425_1-Mistracking_Trim             NaN       NaN
# VISUCI1_S1_20200415_150359_849_1-Tear                         NaN  0.776822
# VISUCI1_S1_20200415_150359_952_1-Tear                         NaN  0.997396
# VISUCI1_S1_20200416_020241_609_1-Mistracking_Trim             NaN       NaN
# VISUCI1_S1_20200416_024506_582_3-Wrinkle_Fold_M...       0.683656       NaN
#
#                                                     Wrinkle/Fold  Unknown  \
# Image_key
# VISUCI1_S1_20191207_050605_819_3-Unknown                     NaN      1.0
# VISUCI1_S1_20191208_123531_849_3-Unknown                     NaN      1.0
# VISUCI1_S1_20191208_172306_479_1-Unknown                     NaN      1.0
# VISUCI1_S1_20191210_174100_732_3-Mistracking                 NaN      NaN
# VISUCI1_S1_20191210_211959_279_3-Wrinkle_Fold           0.498891      NaN
# ...                                                          ...      ...
# VISUCI1_S1_20200414_230853_425_1-Mistracking_Trim            NaN      NaN
# VISUCI1_S1_20200415_150359_849_1-Tear                        NaN      NaN
# VISUCI1_S1_20200415_150359_952_1-Tear                        NaN      NaN
# VISUCI1_S1_20200416_020241_609_1-Mistracking_Trim            NaN      NaN
# VISUCI1_S1_20200416_024506_582_3-Wrinkle_Fold_M...      0.918517      NaN
#
#                                                     Good
# Image_key
# VISUCI1_S1_20191207_050605_819_3-Unknown             NaN
# VISUCI1_S1_20191208_123531_849_3-Unknown             NaN
# VISUCI1_S1_20191208_172306_479_1-Unknown             NaN
# VISUCI1_S1_20191210_174100_732_3-Mistracking         NaN
# VISUCI1_S1_20191210_211959_279_3-Wrinkle_Fold        NaN
# ...                                                  ...
# VISUCI1_S1_20200414_230853_425_1-Mistracking_Trim    NaN
# VISUCI1_S1_20200415_150359_849_1-Tear                NaN
# VISUCI1_S1_20200415_150359_952_1-Tear                NaN
# VISUCI1_S1_20200416_020241_609_1-Mistracking_Trim    NaN
# VISUCI1_S1_20200416_024506_582_3-Wrinkle_Fold_M...   NaN
#
# [150 rows x 7 columns]
# overall summary
#                count  Percentage
# Mistracking       35   23.333333
# Trim              16   10.666667
# Contamination     30   20.000000
# Tear              18   12.000000
# Wrinkle/Fold      18   12.000000
# Unknown           61   40.666667
# Good               1    0.666667
# total            150  100.000000
# Time taken for overall object detection inference for all images 72.940664768219
# Total time taken for all images for complete inference 146.0454864501953
# CPU times: user 6min 4s, sys: 15.9 s, total: 6min 19s
# Wall time: 2min 26s

# %%
# os.remove("summary.csv")

# %%
### ---end of code
