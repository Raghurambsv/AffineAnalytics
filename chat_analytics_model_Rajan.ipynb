# %% [markdown]
# # Feedback Classification using Word2Vec and LSTM

# %% [markdown]
# **What is Word2Vec?**
#
# Word2vec is a group of Deep Learning models developed by Google with the aim of capturing the context of words while at
# the same time proposing a very efficient way of preprocessing raw text data. This model takes as input a large corpus of
# documents like tweets or news articles or feedbacks and generates a vector space of typically several hundred dimensions. Each word in the corpus is being assigned a unique vector in the vector space.
#
#
# The powerful concept behind word2vec is that word vectors that are close to each other in the vector space represent words that are not only of the same meaning but of the same context as well.
#
# Its interesting about the vector representation of words is that it automatically embeds several features that we would normally have to handcraft ourselves. Since word2vec relies on Deep Neural Nets to detect patterns, we can rely on it to detect multiple features on different levels of abstractions.
#
# See the following images for clear justification on how we visualize some word vectors projected on 2D space after a dimensionality reduction.

# %% [markdown]
# ![title](w2v_1.jpg)

# %% [markdown]
# A couple of things to notice:
#
# On the right chart, the words of similar meaning, concept and context are grouped together.
#
# The chart on the left is quite similar to the one on the right except that it translates the syntaxic relationships between words. slow - slowest = short - shortest is such an example.
#
# So, On a more general level, **word2vec** embeds non trivial semantic and syntaxic relationships between words. This results in preserving a rich context.

# %% [raw]
# How our data looks like?
#
#           Feedback                                           Theme
# the dishwasher is still not working	 -------->	Repaired product still not working
#
#
# Felt pushed to buy service plan.
# Didn't listen to me with what I needed
# and way over prised would like a refund	------->        Service charges are too costly

# %% [markdown]
# Problem Statement:
#
# Can we use Word2Vec and LSTMs model to identify these Themes based on the semantic context of the text?
#
# Answer is **YES**

# %% [markdown]
# ********************************************************

# %% [markdown]
# Data used:
#
# 1000 raw feedbacks from the member regarding their issues.
#
# We labelled 500 feedbacks, and now we will try to learn the hidden embeddings to predict **Theme** of other 500 feedbacks.

# %% [markdown]
# *************************************************

# %% [markdown]
# # Approach we will be using:
#
# ## Step 1: Data Shuffling
#
# ## Step 2: Data Cleaning [Lemmatization, Stop Words Removal, Special Character Removal]
#
# ## Step 3: Created Word2Vec Model from the corpus
#
# ## Step 4: Make feature embedding vector for each feedback
#
# ## Step 5: Train model and prediction on test feedback

# %% [markdown]
# Important Libraries to import:
#
# We will make a virtual environment, and we'll need to install these libraries:
#
# **gensim** is a natural language processing python library. It makes text mining, cleaning and modeling very easy. Besides, it provides an implementation of the word2vec model.
#
# **Keras** is a high-level neural networks API, written in Python and capable of running on top of either TensorFlow or Theano. We'll be using it to train our sentiment classifier. In this tutorial, it will run on top of TensorFlow.
#
# **nltk** stands for Natural Language Toolkit. This toolkit is one of the most powerful NLP libraries which contains packages to make machines understand human language and reply to it with an appropriate response. Tokenization, Stemming, Lemmatization, Punctuation, Character count, word count are some of the important features.
#
# **tqdm** is cool progress bar utility package we can use to monitor dataframes creation.

# %%
# Necessary imports
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import keras
from sklearn.feature_extraction.text import CountVectorizer
from keras.preprocessing.text import Tokenizer
from keras.models import Sequential
from keras.layers.core import Dense
from keras.layers import Embedding, LSTM
from sklearn.model_selection import train_test_split
from keras.utils.np_utils import to_categorical
import re
from keras.preprocessing.sequence import pad_sequences
from keras.layers import Dense, Input, LSTM, Embedding, Dropout, Activation
from keras.layers.merge import concatenate
from keras.models import Model
from keras.layers.normalization import BatchNormalization
from keras.callbacks import EarlyStopping, ModelCheckpoint
#from keras.layers import Conv1D, MaxPooling1D, Embedding
import nltk

# %% [markdown]
# ## Reading the Data

# %%
import pandas as pd
df = pd.read_csv('HS_Theme.csv', encoding = 'latin-1')
df.head()
df['Theme'].nunique()
# Out:
# 12

# %%
df.columns = ['respId','feedback','rating', 'Theme']  # Renaming the column Names
len(set(df['Theme']))
# Out:
# 13

# %%
set(df['Theme'])
# Out:
# {'Dissatisfied with service provided even after multiple visits',
#  'Dissatisfied with warranty terms and conditions',
#  'Extremely dissatisifed with experience',
#  'Others',
#  'Parts unavailability or Wrong Part delivered',
#  'Repaired product still not working',
#  'Request for contact back by customer',
#  'Scheduling issue (Call center experience)',
#  'Service charges are too costly',
#  "Technician code of conduct\n(Didn't inspected thoroughly/Racist comments/nasty/came drunk/improper afterworks)",
#  'Technician not having required expertise',
#  'Technician not turning up at all or on scheduled time',
#  nan}

# %%
df.head()
# Out:
#                respId                                           feedback  \
# 0  p3084928113_486992  The repairman left oil smears all over the was...
# 1  p3084928113_457095   The entire process was  Long and drawn out th...
# 2  p3084928113_381320  To whom may correspond, the technician came in...
# 3  p3084928113_428015                the dishwasher is still not working
# 4  p3084928113_499227  I have filled out two of these today.is everyt...
#
#   rating                                              Theme
# 0      3  Technician code of conduct\n(Didn't inspected ...
# 1      1  Dissatisfied with service provided even after ...
# 2      1               Request for contact back by customer
# 3      2                 Repaired product still not working
# 4      1                                             Others

# %% [markdown]
# So this data has 4 columns. <br />
# **respId** : Identifier of each feedback <br />
# **feedback** : raw feedback that we received from the member <br />
# **rating** : rating on a scale of 1-5 provided by the member <br />
# **Theme** : 12 Themes defined by us

# %%
data = df.copy()
data.feedback.fillna('none', inplace=True) # Removing the rows having blank/No feedback

# %% [markdown]
# ### List of all possible Themes defined by us and their count in train data

# %%
j = df.Theme
import collections
j.value_counts()
# Out:
# Scheduling issue (Call center experience)                                                                         89
# Technician not turning up at all or on scheduled time                                                             69
# Extremely dissatisifed with experience                                                                            48
# Dissatisfied with service provided even after multiple visits                                                     45
# Others                                                                                                            43
# Repaired product still not working                                                                                43
# Technician not having required expertise                                                                          38
# Parts unavailability or Wrong Part delivered                                                                      36
# Service charges are too costly                                                                                    32
# Technician code of conduct\n(Didn't inspected thoroughly/Racist comments/nasty/came drunk/improper afterworks)    28
# Request for contact back by customer                                                                              15
# Dissatisfied with warranty terms and conditions                                                                   13
# Name: Theme, dtype: int64

# %% [markdown]
# ### Data Preprocessing Starts
#
# #### Converting all feedback in lowercase
# #### Replace frequently occured feedback removing special characters
# #### Regex to remove special character if any
# #### Removal of custom stop words: Words which occur very frequently in our data like 'The','He','She' as these words don't add anything in the context

# %%
# Apply Data Filtering
data.feedback = data.feedback.apply(lambda x: x.lower())  # Converting all text into lower case
data['feedback'].replace('doesnt','does not',inplace=True,regex=True)
data['feedback'].replace('whats','what is',inplace=True,regex=True)
data['feedback'].replace('canst','cannot',inplace=True,regex=True)
data['feedback'].replace('can\'t','cannot',inplace=True,regex=True)
data['feedback'].replace('n\'t','not',inplace=True,regex=True)
data['feedback'].replace('dont','do not',inplace=True,regex=True)
data['feedback'].replace('\'s',' is',inplace=True,regex=True)
data['feedback'].replace('n\?t','not',inplace=True,regex=True)
data['feedback'].replace('\?s',' is',inplace=True,regex=True)
data['feedback'].replace('ism','i am',inplace=True,regex=True)
data['feedback'].replace('[!"#%\()''*+,-./:;<=>?@\[\]^_`{|}~1234567890’”“′‘\\\]','',inplace=True,regex=True)

#Our custom Stop Words
custom_stop=['a','about','above','after','again','against','all','am','an','and','any','are','aren','as','at','be','because','been','before','being','below','between','both','but','by','d','during','each','few','for','from','further','he','her','here','hers','herself','him','himself','his','i','if','in','into','is','isn','it','its','itself','just','ll','m','ma','me','mightn','mustn','my','myself','needn','now','o','of','on','once','or','other','our','ours','ourselves','out','over','own','re','s','shan','she','should','so','some','such','t','than','that','the','their','theirs','them','themselves','then','there','these','they','this','those','through','to','too','under','until','up','ve','very','wasn','we','were','will','with','won','wouldn','y','yo','your','yours','yourself','yourselves','s','x','n','j','k']

# %% [markdown]
# ##### Word Lemmatizer to extract root words if there are multiple verbs of same words like reading,read

# %%
from nltk.stem.wordnet import WordNetLemmatizer 
lmtzr = WordNetLemmatizer()

# %% [markdown]
# #### Convert each row in a list of words to apply WordNetLemmatizer filter and Stopwords for each word

# %%
data['feedback']=data['feedback'].apply(lambda x : filter(None,x.split(" ")))   # Creating a list of words
data['feedback'] = data.feedback.apply(lambda x :[ lmtzr.lemmatize(word,'v') for word in x]) # Appling the Lemmatizer
data['feedback'] = data.feedback.apply(lambda x: [word for word in x if word not in (custom_stop)]) # Removing StopWords
data['feedback']=data['feedback'].apply(lambda x : " ".join(x)) # Joining to words to get back the feedback

# %%
data.head()
# Out:
#                respId                                           feedback  \
# 0  p3084928113_486992             repairman leave oil smear wash machine
# 1  p3084928113_457095  entire process long draw technician order part...
# 2  p3084928113_381320  whom may correspond technician come look appli...
# 3  p3084928113_428015                          dishwasher still not work
# 4  p3084928113_499227  have fill two todayis everything screw service...
#
#   rating                                              Theme
# 0      3  Technician code of conduct\n(Didn't inspected ...
# 1      1  Dissatisfied with service provided even after ...
# 2      1               Request for contact back by customer
# 3      2                 Repaired product still not working
# 4      1                                             Others

# %% [markdown]
# ### We will remove words which has very few occurences in our whole corpus. Because it might be a spelling mistake. So every word should occur atleast thrice to be considered in our corpus

# %%
import collections
minimum_count = 3
import itertools
str_frequencies = pd.DataFrame(list(collections.Counter(filter(None,list(itertools.chain(*data['feedback'].str.split(' '))))).items()),columns=['word','count'])
low_frequency_words = set(str_frequencies[str_frequencies['count'] < minimum_count]['word'])
len(low_frequency_words)
# Out:
# 1883

# %%
data['stemmed_text_data'] = [' '.join(filter(None,filter(lambda word: word not in low_frequency_words, line))) for line in data['feedback'].str.split(' ')]
data.feedback = data['stemmed_text_data']
del data['stemmed_text_data']

# %% [markdown]
# Before feeding lists of tokens into the word2vec model, we must turn them into LabeledSentence objects beforehand.
# Here's how to do it:

# %%
def labelizeFeedbacks(feedback, label_type):
    labelized = []
    for i,v in tqdm(enumerate(feedback)):
        label = '%s_%s'%(label_type,i)
        labelized.append(LabeledSentence(v, [label]))
    return labelized

# %%
data.Theme[499:] = 'Others'

# %% [markdown]
# Encoding each Theme into a number to pass into the model. We will decode it once we get the results to get our original theme.

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
le.fit(data['Theme'].astype(str))
data.Theme = le.transform(data['Theme'].astype(str))
#df[cat].astype(str)

# %%
data.Theme[1:10]
# Out:
# 1     0
# 2     6
# 3     5
# 4     3
# 5    10
# 6     2
# 7     8
# 8     3
# 9    10
# Name: Theme, dtype: int64

# %%
data['Theme'].value_counts()
# Out:
# 3     542
# 7      89
# 11     69
# 2      48
# 0      45
# 5      43
# 10     38
# 4      36
# 8      32
# 9      28
# 6      15
# 1      13
# Name: Theme, dtype: int64

# %%
data['feedback']=data['feedback'].apply(lambda x : list(filter(None,x.split(" "))))

# %%
from gensim.models.doc2vec import LabeledSentence, Doc2Vec

# %%
X_train = data.feedback[0:499]
X_test = data.feedback[499:]
Y_train = data.Theme[0:499]
Y_test = data.Theme[499:]

# %%
from tqdm import tqdm
tqdm.pandas(desc="progress-bar")

# %%
x_train = labelizeFeedbacks(X_train, 'TRAIN')
x_test = labelizeFeedbacks(X_test, 'TEST')
x_whole = labelizeFeedbacks(data.feedback, 'TEST_1')
# Out:
# 0it [00:00, ?it/s]/home/bmalli1/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `LabeledSentence` (Class will be removed in 4.0.0, use TaggedDocument instead).
#   """
# 499it [00:00, 119905.91it/s]
# 499it [00:00, 264864.30it/s]
# 998it [00:00, 279284.45it/s]

# %%
import gensim                                       # importing the word2vec model gensim class
from gensim.models.word2vec import Word2Vec

# %% [markdown]
# ### Training word2vec Model

# %%
input_size = 300
model1 = Word2Vec(data.feedback , min_count=10 , size = input_size ,  alpha=0.2988 , window=100 , workers=8, seed=2178977)

# %%
model1.wv.vocab
# Out:
# {'repairman': <gensim.models.keyedvectors.Vocab at 0x7f0d947de390>,
#  'leave': <gensim.models.keyedvectors.Vocab at 0x7f0d947de080>,
#  'wash': <gensim.models.keyedvectors.Vocab at 0x7f0d947e2be0>,
#  'machine': <gensim.models.keyedvectors.Vocab at 0x7f0d947e2c50>,
#  'entire': <gensim.models.keyedvectors.Vocab at 0x7f0d947e2cf8>,
#  'process': <gensim.models.keyedvectors.Vocab at 0x7f0d947e2da0>,
#  'long': <gensim.models.keyedvectors.Vocab at 0x7f0d947e2e48>,
#  'technician': <gensim.models.keyedvectors.Vocab at 0x7f0d947e2f28>,
#  'order': <gensim.models.keyedvectors.Vocab at 0x7f0d947e2f60>,
#  'part': <gensim.models.keyedvectors.Vocab at 0x7f0d947e2f98>,
#  'sear': <gensim.models.keyedvectors.Vocab at 0x7f0d947e2fd0>,
#  'cancel': <gensim.models.keyedvectors.Vocab at 0x7f0d947e25c0>,
#  'have': <gensim.models.keyedvectors.Vocab at 0x7f0d947e2668>,
#  'come': <gensim.models.keyedvectors.Vocab at 0x7f0d947e26a0>,
#  'back': <gensim.models.keyedvectors.Vocab at 0x7f0d947e26d8>,
#  'look': <gensim.models.keyedvectors.Vocab at 0x7f0d947e2748>,
#  'put': <gensim.models.keyedvectors.Vocab at 0x7f0d947e2780>,
#  'it\x83': <gensim.models.keyedvectors.Vocab at 0x7f0d947e27f0>,
#  'still': <gensim.models.keyedvectors.Vocab at 0x7f0d947e29b0>,
#  'not': <gensim.models.keyedvectors.Vocab at 0x7f0d947e2978>,
#  'fix': <gensim.models.keyedvectors.Vocab at 0x7f0d947e29e8>,
#  'completely': <gensim.models.keyedvectors.Vocab at 0x7f0d947e2a58>,
#  'may': <gensim.models.keyedvectors.Vocab at 0x7f0d947e2320>,
#  'appliance': <gensim.models.keyedvectors.Vocab at 0x7f0d947e2358>,
#  'make': <gensim.models.keyedvectors.Vocab at 0x7f0d947e2400>,
#  'no': <gensim.models.keyedvectors.Vocab at 0x7f0d947e2438>,
#  'go': <gensim.models.keyedvectors.Vocab at 0x7f0d947e2470>,
#  'previous': <gensim.models.keyedvectors.Vocab at 0x7f0d947e24a8>,
#  'state': <gensim.models.keyedvectors.Vocab at 0x7f0d947e24e0>,
#  'complain': <gensim.models.keyedvectors.Vocab at 0x7f0d947e2518>,
#  'refrigerator': <gensim.models.keyedvectors.Vocab at 0x7f0d947e2048>,
#  'garage': <gensim.models.keyedvectors.Vocab at 0x7f0d947e20b8>,
#  'cold': <gensim.models.keyedvectors.Vocab at 0x7f0d947e2080>,
#  'work': <gensim.models.keyedvectors.Vocab at 0x7f0d947e20f0>,
#  'even': <gensim.models.keyedvectors.Vocab at 0x7f0d947e2128>,
#  'perform': <gensim.models.keyedvectors.Vocab at 0x7f0d947e2160>,
#  'point': <gensim.models.keyedvectors.Vocab at 0x7f0d947e2198>,
#  'talk': <gensim.models.keyedvectors.Vocab at 0x7f0d947e21d0>,
#  'representative': <gensim.models.keyedvectors.Vocab at 0x7f0d947e2208>,
#  'do': <gensim.models.keyedvectors.Vocab at 0x7f0d947e2240>,
#  'get': <gensim.models.keyedvectors.Vocab at 0x7f0d947e0ef0>,
#  'much': <gensim.models.keyedvectors.Vocab at 0x7f0d947e0f28>,
#  'help': <gensim.models.keyedvectors.Vocab at 0x7f0d947e0828>,
#  'fact': <gensim.models.keyedvectors.Vocab at 0x7f0d947e0898>,
#  'only': <gensim.models.keyedvectors.Vocab at 0x7f0d947e08d0>,
#  'offer': <gensim.models.keyedvectors.Vocab at 0x7f0d947e0978>,
#  'pay': <gensim.models.keyedvectors.Vocab at 0x7f0d947e0a20>,
#  'due': <gensim.models.keyedvectors.Vocab at 0x7f0d947e0ac8>,
#  'warranty': <gensim.models.keyedvectors.Vocab at 0x7f0d947e0b00>,
#  'compressor': <gensim.models.keyedvectors.Vocab at 0x7f0d947e0b38>,
#  'labor': <gensim.models.keyedvectors.Vocab at 0x7f0d947e0b70>,
#  'which': <gensim.models.keyedvectors.Vocab at 0x7f0d947e0be0>,
#  'when': <gensim.models.keyedvectors.Vocab at 0x7f0d947e0c18>,
#  'total': <gensim.models.keyedvectors.Vocab at 0x7f0d947e0c50>,
#  'would': <gensim.models.keyedvectors.Vocab at 0x7f0d947e0c88>,
#  '$': <gensim.models.keyedvectors.Vocab at 0x7f0d947e0cf8>,
#  'repair': <gensim.models.keyedvectors.Vocab at 0x7f0d947e0da0>,
#  'last': <gensim.models.keyedvectors.Vocab at 0x7f0d947e0e10>,
#  'year': <gensim.models.keyedvectors.Vocab at 0x7f0d947e0e48>,
#  'half': <gensim.models.keyedvectors.Vocab at 0x7f0d947e0e80>,
#  'act': <gensim.models.keyedvectors.Vocab at 0x7f0d947e0eb8>,
#  'ago': <gensim.models.keyedvectors.Vocab at 0x7f0d947e0198>,
#  'want': <gensim.models.keyedvectors.Vocab at 0x7f0d947e01d0>,
#  'see': <gensim.models.keyedvectors.Vocab at 0x7f0d947e0208>,
#  'something': <gensim.models.keyedvectors.Vocab at 0x7f0d947e0240>,
#  'else': <gensim.models.keyedvectors.Vocab at 0x7f0d947e02b0>,
#  'can': <gensim.models.keyedvectors.Vocab at 0x7f0d947e02e8>,
#  'please': <gensim.models.keyedvectors.Vocab at 0x7f0d947e0320>,
#  'contact': <gensim.models.keyedvectors.Vocab at 0x7f0d947e0358>,
#  'phone': <gensim.models.keyedvectors.Vocab at 0x7f0d947e0390>,
#  'number': <gensim.models.keyedvectors.Vocab at 0x7f0d947e03c8>,
#  'thank': <gensim.models.keyedvectors.Vocab at 0x7f0d947e0438>,
#  'you': <gensim.models.keyedvectors.Vocab at 0x7f0d947e0470>,
#  'appreciate': <gensim.models.keyedvectors.Vocab at 0x7f0d947e04e0>,
#  'dishwasher': <gensim.models.keyedvectors.Vocab at 0x7f0d947e0518>,
#  'two': <gensim.models.keyedvectors.Vocab at 0x7f0d947e0550>,
#  'everything': <gensim.models.keyedvectors.Vocab at 0x7f0d947e0588>,
#  'service': <gensim.models.keyedvectors.Vocab at 0x7f0d947e05c0>,
#  'charge': <gensim.models.keyedvectors.Vocab at 0x7f0d947e05f8>,
#  'next': <gensim.models.keyedvectors.Vocab at 0x7f0d947e06a0>,
#  'time': <gensim.models.keyedvectors.Vocab at 0x7f0d947e06d8>,
#  'u': <gensim.models.keyedvectors.Vocab at 0x7f0d947e0710>,
#  'send': <gensim.models.keyedvectors.Vocab at 0x7f0d947e0748>,
#  'man': <gensim.models.keyedvectors.Vocab at 0x7f0d947e0780>,
#  'sure': <gensim.models.keyedvectors.Vocab at 0x7f0d947e07b8>,
#  'know': <gensim.models.keyedvectors.Vocab at 0x7f0d947e07f0>,
#  'what': <gensim.models.keyedvectors.Vocab at 0x7f0d947e0128>,
#  'upset': <gensim.models.keyedvectors.Vocab at 0x7f0d947e4828>,
#  'load': <gensim.models.keyedvectors.Vocab at 0x7f0d947e4860>,
#  'water': <gensim.models.keyedvectors.Vocab at 0x7f0d947e4898>,
#  'need': <gensim.models.keyedvectors.Vocab at 0x7f0d947e48d0>,
#  'train': <gensim.models.keyedvectors.Vocab at 0x7f0d947e4940>,
#  'whole': <gensim.models.keyedvectors.Vocab at 0x7f0d947e49b0>,
#  'deal': <gensim.models.keyedvectors.Vocab at 0x7f0d947e49e8>,
#  'worst': <gensim.models.keyedvectors.Vocab at 0x7f0d947e4a20>,
#  'experience': <gensim.models.keyedvectors.Vocab at 0x7f0d947e4a90>,
#  'ever': <gensim.models.keyedvectors.Vocab at 0x7f0d947e4ac8>,
#  'never': <gensim.models.keyedvectors.Vocab at 0x7f0d947e4ba8>,
#  'clean': <gensim.models.keyedvectors.Vocab at 0x7f0d947e4be0>,
#  'tech': <gensim.models.keyedvectors.Vocab at 0x7f0d947e4c18>,
#  'finish': <gensim.models.keyedvectors.Vocab at 0x7f0d947e4c50>,
#  'less': <gensim.models.keyedvectors.Vocab at 0x7f0d947e4c88>,
#  'hour': <gensim.models.keyedvectors.Vocab at 0x7f0d947e4cc0>,
#  'require': <gensim.models.keyedvectors.Vocab at 0x7f0d947e4cf8>,
#  'guess': <gensim.models.keyedvectors.Vocab at 0x7f0d947e4d30>,
#  'off': <gensim.models.keyedvectors.Vocab at 0x7f0d947e4dd8>,
#  'second': <gensim.models.keyedvectors.Vocab at 0x7f0d947e4e10>,
#  'rat': <gensim.models.keyedvectors.Vocab at 0x7f0d947e4e48>,
#  'dryer': <gensim.models.keyedvectors.Vocab at 0x7f0d947e4f28>,
#  'heat': <gensim.models.keyedvectors.Vocab at 0x7f0d947e4f60>,
#  'nice': <gensim.models.keyedvectors.Vocab at 0x7f0d947e4fd0>,
#  'appear': <gensim.models.keyedvectors.Vocab at 0x7f0d947e4668>,
#  'knowledgeable': <gensim.models.keyedvectors.Vocab at 0x7f0d947e46a0>,
#  'report': <gensim.models.keyedvectors.Vocab at 0x7f0d947e46d8>,
#  'first': <gensim.models.keyedvectors.Vocab at 0x7f0d947e4748>,
#  'advise': <gensim.models.keyedvectors.Vocab at 0x7f0d947e47b8>,
#  'replace': <gensim.models.keyedvectors.Vocab at 0x7f0d947e47f0>,
#  'cost': <gensim.models.keyedvectors.Vocab at 0x7f0d947e42b0>,
#  'check': <gensim.models.keyedvectors.Vocab at 0x7f0d947e42e8>,
#  'purchase': <gensim.models.keyedvectors.Vocab at 0x7f0d947e4320>,
#  'new': <gensim.models.keyedvectors.Vocab at 0x7f0d947e4358>,
#  'another': <gensim.models.keyedvectors.Vocab at 0x7f0d947e4390>,
#  'problem': <gensim.models.keyedvectors.Vocab at 0x7f0d947e4438>,
#  'person': <gensim.models.keyedvectors.Vocab at 0x7f0d947e4400>,
#  'morning': <gensim.models.keyedvectors.Vocab at 0x7f0d947e4470>,
#  'company': <gensim.models.keyedvectors.Vocab at 0x7f0d947e4518>,
#  'food': <gensim.models.keyedvectors.Vocab at 0x7f0d947e45c0>,
#  'actually': <gensim.models.keyedvectors.Vocab at 0x7f0d947e45f8>,
#  'who': <gensim.models.keyedvectors.Vocab at 0x7f0d947e4630>,
#  'tell': <gensim.models.keyedvectors.Vocab at 0x7f0d947e4048>,
#  'same': <gensim.models.keyedvectors.Vocab at 0x7f0d947e4080>,
#  'thing': <gensim.models.keyedvectors.Vocab at 0x7f0d947e40f0>,
#  'reason': <gensim.models.keyedvectors.Vocab at 0x7f0d947e4160>,
#  'call': <gensim.models.keyedvectors.Vocab at 0x7f0d947e41d0>,
#  'helpful': <gensim.models.keyedvectors.Vocab at 0x7f0d947e4208>,
#  'someone': <gensim.models.keyedvectors.Vocab at 0x7f0d947e4240>,
#  'give': <gensim.models.keyedvectors.Vocab at 0x7f0d947e3f28>,
#  'customer': <gensim.models.keyedvectors.Vocab at 0x7f0d947e3f60>,
#  'solve': <gensim.models.keyedvectors.Vocab at 0x7f0d947e3f98>,
#  'trip': <gensim.models.keyedvectors.Vocab at 0x7f0d947e3fd0>,
#  'spend': <gensim.models.keyedvectors.Vocab at 0x7f0d947e3828>,
#  'nothing': <gensim.models.keyedvectors.Vocab at 0x7f0d947e3860>,
#  'ice': <gensim.models.keyedvectors.Vocab at 0x7f0d947e38d0>,
#  'think': <gensim.models.keyedvectors.Vocab at 0x7f0d947e3940>,
#  'way': <gensim.models.keyedvectors.Vocab at 0x7f0d947e3978>,
#  'diagnostic': <gensim.models.keyedvectors.Vocab at 0x7f0d947e39b0>,
#  'fee': <gensim.models.keyedvectors.Vocab at 0x7f0d947e39e8>,
#  'right': <gensim.models.keyedvectors.Vocab at 0x7f0d947e3a20>,
#  'technicians': <gensim.models.keyedvectors.Vocab at 0x7f0d947e3a58>,
#  'week': <gensim.models.keyedvectors.Vocab at 0x7f0d947e3a90>,
#  'take': <gensim.models.keyedvectors.Vocab at 0x7f0d947e3ac8>,
#  'weeks': <gensim.models.keyedvectors.Vocab at 0x7f0d947e3b38>,
#  'use': <gensim.models.keyedvectors.Vocab at 0x7f0d947e3b70>,
#  'hours': <gensim.models.keyedvectors.Vocab at 0x7f0d947e3be0>,
#  'didn\x83t': <gensim.models.keyedvectors.Vocab at 0x7f0d947e3c50>,
#  'say': <gensim.models.keyedvectors.Vocab at 0x7f0d947e3c88>,
#  'really': <gensim.models.keyedvectors.Vocab at 0x7f0d947e3cf8>,
#  'couldn\x83t': <gensim.models.keyedvectors.Vocab at 0x7f0d947e3d30>,
#  'wait': <gensim.models.keyedvectors.Vocab at 0x7f0d947e3d68>,
#  'four': <gensim.models.keyedvectors.Vocab at 0x7f0d947e3da0>,
#  'without': <gensim.models.keyedvectors.Vocab at 0x7f0d947e3dd8>,
#  'don\x83t': <gensim.models.keyedvectors.Vocab at 0x7f0d947e3e10>,
#  'guy': <gensim.models.keyedvectors.Vocab at 0x7f0d947e3e80>,
#  'buy': <gensim.models.keyedvectors.Vocab at 0x7f0d947e3ef0>,
#  'one': <gensim.models.keyedvectors.Vocab at 0x7f0d947e37f0>,
#  'minutes': <gensim.models.keyedvectors.Vocab at 0x7f0d947e3048>,
#  'attempt': <gensim.models.keyedvectors.Vocab at 0x7f0d947e3080>,
#  'additional': <gensim.models.keyedvectors.Vocab at 0x7f0d947e30f0>,
#  'request': <gensim.models.keyedvectors.Vocab at 0x7f0d947e30b8>,
#  'find': <gensim.models.keyedvectors.Vocab at 0x7f0d947e3128>,
#  'washer': <gensim.models.keyedvectors.Vocab at 0x7f0d947e3160>,
#  'bad': <gensim.models.keyedvectors.Vocab at 0x7f0d947e3198>,
#  'how': <gensim.models.keyedvectors.Vocab at 0x7f0d947e3208>,
#  'full': <gensim.models.keyedvectors.Vocab at 0x7f0d947e31d0>,
#  'extremely': <gensim.models.keyedvectors.Vocab at 0x7f0d947e3240>,
#  'disappoint': <gensim.models.keyedvectors.Vocab at 0x7f0d947e32e8>,
#  'recommend': <gensim.models.keyedvectors.Vocab at 0x7f0d947e3320>,
#  'anyone': <gensim.models.keyedvectors.Vocab at 0x7f0d947e3400>,
#  'good': <gensim.models.keyedvectors.Vocab at 0x7f0d947e3470>,
#  'replacement': <gensim.models.keyedvectors.Vocab at 0x7f0d947e34a8>,
#  'instal': <gensim.models.keyedvectors.Vocab at 0x7f0d947e3518>,
#  'more': <gensim.models.keyedvectors.Vocab at 0x7f0d947e3550>,
#  'old': <gensim.models.keyedvectors.Vocab at 0x7f0d947e35c0>,
#  'years': <gensim.models.keyedvectors.Vocab at 0x7f0d947e35f8>,
#  'well': <gensim.models.keyedvectors.Vocab at 0x7f0d947e3630>,
#  'brand': <gensim.models.keyedvectors.Vocab at 0x7f0d947e36a0>,
#  'gas': <gensim.models.keyedvectors.Vocab at 0x7f0d947e36d8>,
#  'range': <gensim.models.keyedvectors.Vocab at 0x7f0d947e3710>,
#  'happen': <gensim.models.keyedvectors.Vocab at 0x7f0d947e3748>,
#  'could': <gensim.models.keyedvectors.Vocab at 0x7f0d947e3780>,
#  'try': <gensim.models.keyedvectors.Vocab at 0x7f0d947e1da0>,
#  'oven': <gensim.models.keyedvectors.Vocab at 0x7f0d947e1dd8>,
#  'test': <gensim.models.keyedvectors.Vocab at 0x7f0d947e1e10>,
#  'totally': <gensim.models.keyedvectors.Vocab at 0x7f0d947e1e48>,
#  'why': <gensim.models.keyedvectors.Vocab at 0x7f0d947e1e80>,
#  'able': <gensim.models.keyedvectors.Vocab at 0x7f0d947e1eb8>,
#  'wasnot': <gensim.models.keyedvectors.Vocab at 0x7f0d947e1ef0>,
#  'inform': <gensim.models.keyedvectors.Vocab at 0x7f0d947e1f28>,
#  'low': <gensim.models.keyedvectors.Vocab at 0x7f0d947e13c8>,
#  'high': <gensim.models.keyedvectors.Vocab at 0x7f0d947e1400>,
#  'resolve': <gensim.models.keyedvectors.Vocab at 0x7f0d947e1438>,
#  'cover': <gensim.models.keyedvectors.Vocab at 0x7f0d947e1470>,
#  'business': <gensim.models.keyedvectors.Vocab at 0x7f0d947e14a8>,
#  'terrible': <gensim.models.keyedvectors.Vocab at 0x7f0d947e14e0>,
#  'expensive': <gensim.models.keyedvectors.Vocab at 0x7f0d947e1518>,
#  'later': <gensim.models.keyedvectors.Vocab at 0x7f0d947e15c0>,
#  'poor': <gensim.models.keyedvectors.Vocab at 0x7f0d947e15f8>,
#  'doesn\x83t': <gensim.models.keyedvectors.Vocab at 0x7f0d947e1630>,
#  'th': <gensim.models.keyedvectors.Vocab at 0x7f0d947e1668>,
#  'quality': <gensim.models.keyedvectors.Vocab at 0x7f0d947e16a0>,
#  'appointments': <gensim.models.keyedvectors.Vocab at 0x7f0d947e16d8>,
#  'techs': <gensim.models.keyedvectors.Vocab at 0x7f0d947e1710>,
#  'run': <gensim.models.keyedvectors.Vocab at 0x7f0d947e1780>,
#  'rude': <gensim.models.keyedvectors.Vocab at 0x7f0d947e17f0>,
#  'afternoon': <gensim.models.keyedvectors.Vocab at 0x7f0d947e1828>,
#  'show': <gensim.models.keyedvectors.Vocab at 0x7f0d947e18d0>,
#  'reschedule': <gensim.models.keyedvectors.Vocab at 0x7f0d947e19b0>,
#  'frustrate': <gensim.models.keyedvectors.Vocab at 0x7f0d947e19e8>,
#  'day': <gensim.models.keyedvectors.Vocab at 0x7f0d947e1a20>,
#  'fault': <gensim.models.keyedvectors.Vocab at 0x7f0d947e1a58>,
#  'donot': <gensim.models.keyedvectors.Vocab at 0x7f0d947e1a90>,
#  'since': <gensim.models.keyedvectors.Vocab at 0x7f0d947e1ac8>,
#  'claim': <gensim.models.keyedvectors.Vocab at 0x7f0d947e1b00>,
#  'money': <gensim.models.keyedvectors.Vocab at 0x7f0d947e1b38>,
#  'seem': <gensim.models.keyedvectors.Vocab at 0x7f0d947e1b70>,
#  'care': <gensim.models.keyedvectors.Vocab at 0x7f0d947e1ba8>,
#  'many': <gensim.models.keyedvectors.Vocab at 0x7f0d947e1c18>,
#  'keep': <gensim.models.keyedvectors.Vocab at 0x7f0d947e1c50>,
#  'break': <gensim.models.keyedvectors.Vocab at 0x7f0d947e1c88>,
#  'promise': <gensim.models.keyedvectors.Vocab at 0x7f0d947e1cf8>,
#  'several': <gensim.models.keyedvectors.Vocab at 0x7f0d947e1d68>,
#  'almost': <gensim.models.keyedvectors.Vocab at 0x7f0d947e1320>,
#  'arrive': <gensim.models.keyedvectors.Vocab at 0x7f0d947e1390>,
#  'appointment': <gensim.models.keyedvectors.Vocab at 0x7f0d947e1080>,
#  'people': <gensim.models.keyedvectors.Vocab at 0x7f0d947e10f0>,
#  'problems': <gensim.models.keyedvectors.Vocab at 0x7f0d947e1160>,
#  'past': <gensim.models.keyedvectors.Vocab at 0x7f0d947e1208>,
#  'today': <gensim.models.keyedvectors.Vocab at 0x7f0d947e1240>,
#  'couldnot': <gensim.models.keyedvectors.Vocab at 0x7f0d947e1278>,
#  'home': <gensim.models.keyedvectors.Vocab at 0x7f0d947e12b0>,
#  'twice': <gensim.models.keyedvectors.Vocab at 0x7f0d947e12e8>,
#  'center': <gensim.models.keyedvectors.Vocab at 0x7f0d947e8cf8>,
#  'situation': <gensim.models.keyedvectors.Vocab at 0x7f0d947e8d30>,
#  'most': <gensim.models.keyedvectors.Vocab at 0x7f0d947e8da0>,
#  'unacceptable': <gensim.models.keyedvectors.Vocab at 0x7f0d947e8dd8>,
#  'days': <gensim.models.keyedvectors.Vocab at 0x7f0d947e8e10>,
#  'didnot': <gensim.models.keyedvectors.Vocab at 0x7f0d947e8e48>,
#  'also': <gensim.models.keyedvectors.Vocab at 0x7f0d947e8e80>,
#  'text': <gensim.models.keyedvectors.Vocab at 0x7f0d947e8eb8>,
#  'around': <gensim.models.keyedvectors.Vocab at 0x7f0d947e8ef0>,
#  'house': <gensim.models.keyedvectors.Vocab at 0x7f0d947e8f28>,
#  'name': <gensim.models.keyedvectors.Vocab at 0x7f0d947e8f60>,
#  'feel': <gensim.models.keyedvectors.Vocab at 0x7f0d947e8f98>,
#  'felt': <gensim.models.keyedvectors.Vocab at 0x7f0d947e8fd0>,
#  'push': <gensim.models.keyedvectors.Vocab at 0x7f0d947e8198>,
#  'plan': <gensim.models.keyedvectors.Vocab at 0x7f0d947e81d0>,
#  'like': <gensim.models.keyedvectors.Vocab at 0x7f0d947e8240>,
#  'refund': <gensim.models.keyedvectors.Vocab at 0x7f0d947e8278>,
#  'visit': <gensim.models.keyedvectors.Vocab at 0x7f0d947e82b0>,
#  'install': <gensim.models.keyedvectors.Vocab at 0x7f0d947e82e8>,
#  'transfer': <gensim.models.keyedvectors.Vocab at 0x7f0d947e8320>,
#  'hang': <gensim.models.keyedvectors.Vocab at 0x7f0d947e83c8>,
#  'truck': <gensim.models.keyedvectors.Vocab at 0x7f0d947e8390>,
#  'worse': <gensim.models.keyedvectors.Vocab at 0x7f0d947e8438>,
#  'multiple': <gensim.models.keyedvectors.Vocab at 0x7f0d947e8470>,
#  'finally': <gensim.models.keyedvectors.Vocab at 0x7f0d947e84a8>,
#  'heater': <gensim.models.keyedvectors.Vocab at 0x7f0d947e84e0>,
#  'computer': <gensim.models.keyedvectors.Vocab at 0x7f0d947e8518>,
#  'board': <gensim.models.keyedvectors.Vocab at 0x7f0d947e8550>,
#  'microwave': <gensim.models.keyedvectors.Vocab at 0x7f0d947e8588>,
#  'extend': <gensim.models.keyedvectors.Vocab at 0x7f0d947e85c0>,
#  'kind': <gensim.models.keyedvectors.Vocab at 0x7f0d947e85f8>,
#  'case': <gensim.models.keyedvectors.Vocab at 0x7f0d947e8630>,
#  'i\x83m': <gensim.models.keyedvectors.Vocab at 0x7f0d947e8668>,
#  'down': <gensim.models.keyedvectors.Vocab at 0x7f0d947e86d8>,
#  'already': <gensim.models.keyedvectors.Vocab at 0x7f0d947e86a0>,
#  'issue': <gensim.models.keyedvectors.Vocab at 0x7f0d947e8710>,
#  'stave': <gensim.models.keyedvectors.Vocab at 0x7f0d947e8780>,
#  'ask': <gensim.models.keyedvectors.Vocab at 0x7f0d947e87b8>,
#  'different': <gensim.models.keyedvectors.Vocab at 0x7f0d947e87f0>,
#  'handle': <gensim.models.keyedvectors.Vocab at 0x7f0d947e8828>,
#  'stop': <gensim.models.keyedvectors.Vocab at 0x7f0d947e8860>,
#  'however': <gensim.models.keyedvectors.Vocab at 0x7f0d947e8898>,
#  'happy': <gensim.models.keyedvectors.Vocab at 0x7f0d947e88d0>,
#  'pm': <gensim.models.keyedvectors.Vocab at 0x7f0d947e8908>,
#  'change': <gensim.models.keyedvectors.Vocab at 0x7f0d947e8940>,
#  'email': <gensim.models.keyedvectors.Vocab at 0x7f0d947e8978>,
#  'customers': <gensim.models.keyedvectors.Vocab at 0x7f0d947e89b0>,
#  'answer': <gensim.models.keyedvectors.Vocab at 0x7f0d947e89e8>,
#  'question': <gensim.models.keyedvectors.Vocab at 0x7f0d947e8a20>,
#  'months': <gensim.models.keyedvectors.Vocab at 0x7f0d947e8a58>,
#  'joke': <gensim.models.keyedvectors.Vocab at 0x7f0d947e8ac8>,
#  'anything': <gensim.models.keyedvectors.Vocab at 0x7f0d947e8b00>,
#  'instead': <gensim.models.keyedvectors.Vocab at 0x7f0d947e8b38>,
#  'prior': <gensim.models.keyedvectors.Vocab at 0x7f0d947e8b70>,
#  'turn': <gensim.models.keyedvectors.Vocab at 0x7f0d947e8be0>,
#  'treat': <gensim.models.keyedvectors.Vocab at 0x7f0d947e8c18>,
#  'laundry': <gensim.models.keyedvectors.Vocab at 0x7f0d947e8c50>,
#  'hold': <gensim.models.keyedvectors.Vocab at 0x7f0d947e8048>,
#  'expect': <gensim.models.keyedvectors.Vocab at 0x7f0d947e8080>,
#  'month': <gensim.models.keyedvectors.Vocab at 0x7f0d947e80b8>,
#  'horrible': <gensim.models.keyedvectors.Vocab at 0x7f0d947eb7b8>,
#  'appliances': <gensim.models.keyedvectors.Vocab at 0x7f0d947eb7f0>,
#  'contract': <gensim.models.keyedvectors.Vocab at 0x7f0d947eb860>,
#  'wonder': <gensim.models.keyedvectors.Vocab at 0x7f0d947eb828>,
#  'close': <gensim.models.keyedvectors.Vocab at 0x7f0d947eb908>,
#  'store': <gensim.models.keyedvectors.Vocab at 0x7f0d947eb940>,
#  'numerous': <gensim.models.keyedvectors.Vocab at 0x7f0d947eb978>,
#  'lack': <gensim.models.keyedvectors.Vocab at 0x7f0d947eb9e8>,
#  'though': <gensim.models.keyedvectors.Vocab at 0x7f0d947eba58>,
#  'leak': <gensim.models.keyedvectors.Vocab at 0x7f0d947eba90>,
#  'damage': <gensim.models.keyedvectors.Vocab at 0x7f0d947ebac8>,
#  'floor': <gensim.models.keyedvectors.Vocab at 0x7f0d947ebb00>,
#  'notice': <gensim.models.keyedvectors.Vocab at 0x7f0d943460f0>,
#  'available': <gensim.models.keyedvectors.Vocab at 0x7f0d94351860>,
#  'january': <gensim.models.keyedvectors.Vocab at 0x7f0d94351668>,
#  'freezer': <gensim.models.keyedvectors.Vocab at 0x7f0d943519e8>,
#  'great': <gensim.models.keyedvectors.Vocab at 0x7f0d94351278>,
#  'online': <gensim.models.keyedvectors.Vocab at 0x7f0d94351a58>,
#  'absolutely': <gensim.models.keyedvectors.Vocab at 0x7f0d943510f0>,
#  'late': <gensim.models.keyedvectors.Vocab at 0x7f0d94351e48>,
#  'info': <gensim.models.keyedvectors.Vocab at 0x7f0d94351710>,
#  'wrong': <gensim.models.keyedvectors.Vocab at 0x7f0d94351da0>,
#  'correct': <gensim.models.keyedvectors.Vocab at 0x7f0d943512b0>,
#  'local': <gensim.models.keyedvectors.Vocab at 0x7f0d94312f60>,
#  'live': <gensim.models.keyedvectors.Vocab at 0x7f0d94312fd0>,
#  'discuss': <gensim.models.keyedvectors.Vocab at 0x7f0d947ebb38>,
#  'job': <gensim.models.keyedvectors.Vocab at 0x7f0d947ebb70>,
#  'hard': <gensim.models.keyedvectors.Vocab at 0x7f0d947ebbe0>,
#  'deliver': <gensim.models.keyedvectors.Vocab at 0x7f0d947ebc18>,
#  'least': <gensim.models.keyedvectors.Vocab at 0x7f0d947ebc50>,
#  'lie': <gensim.models.keyedvectors.Vocab at 0x7f0d947ebc88>,
#  'three': <gensim.models.keyedvectors.Vocab at 0x7f0d947ebcc0>,
#  'end': <gensim.models.keyedvectors.Vocab at 0x7f0d947ebcf8>,
#  'schedule': <gensim.models.keyedvectors.Vocab at 0x7f0d947ebd30>,
#  'error': <gensim.models.keyedvectors.Vocab at 0x7f0d947ebda0>,
#  'understand': <gensim.models.keyedvectors.Vocab at 0x7f0d947ebdd8>,
#  'message': <gensim.models.keyedvectors.Vocab at 0x7f0d947ebe48>,
#  'clear': <gensim.models.keyedvectors.Vocab at 0x7f0d947ebe80>,
#  'open': <gensim.models.keyedvectors.Vocab at 0x7f0d947ebeb8>,
#  'five': <gensim.models.keyedvectors.Vocab at 0x7f0d947ebf60>,
#  'type': <gensim.models.keyedvectors.Vocab at 0x7f0d947ebf98>,
#  'suppose': <gensim.models.keyedvectors.Vocab at 0x7f0d947eb320>,
#  'waste': <gensim.models.keyedvectors.Vocab at 0x7f0d947eb390>,
#  'lose': <gensim.models.keyedvectors.Vocab at 0x7f0d947eb3c8>,
#  'notify': <gensim.models.keyedvectors.Vocab at 0x7f0d947eb400>,
#  'arrival': <gensim.models.keyedvectors.Vocab at 0x7f0d947eb438>,
#  'maintenance': <gensim.models.keyedvectors.Vocab at 0x7f0d947eb470>,
#  'record': <gensim.models.keyedvectors.Vocab at 0x7f0d947eb4e0>,
#  'longer': <gensim.models.keyedvectors.Vocab at 0x7f0d947eb518>,
#  'continue': <gensim.models.keyedvectors.Vocab at 0x7f0d947eb550>,
#  'agreement': <gensim.models.keyedvectors.Vocab at 0x7f0d947eb588>,
#  'every': <gensim.models.keyedvectors.Vocab at 0x7f0d947eb5f8>,
#  '&': <gensim.models.keyedvectors.Vocab at 0x7f0d947eb630>,
#  'front': <gensim.models.keyedvectors.Vocab at 0x7f0d947eb668>,
#  'bring': <gensim.models.keyedvectors.Vocab at 0x7f0d947eb6a0>,
#  'dec': <gensim.models.keyedvectors.Vocab at 0x7f0d947eb6d8>,
#  'pump': <gensim.models.keyedvectors.Vocab at 0x7f0d947eb780>,
#  'line': <gensim.models.keyedvectors.Vocab at 0x7f0d947eb048>,
#  'set': <gensim.models.keyedvectors.Vocab at 0x7f0d947eb080>,
#  'plus': <gensim.models.keyedvectors.Vocab at 0x7f0d947eb0b8>,
#  'dissatisfy': <gensim.models.keyedvectors.Vocab at 0x7f0d947eb0f0>,
#  'hope': <gensim.models.keyedvectors.Vocab at 0x7f0d947eb128>,
#  'doesnot': <gensim.models.keyedvectors.Vocab at 0x7f0d947eb160>,
#  'cause': <gensim.models.keyedvectors.Vocab at 0x7f0d947eb198>,
#  'indicate': <gensim.models.keyedvectors.Vocab at 0x7f0d947eb1d0>,
#  'us': <gensim.models.keyedvectors.Vocab at 0x7f0d947eb278>,
#  'clothe': <gensim.models.keyedvectors.Vocab at 0x7f0d947ecf98>,
#  'bill': <gensim.models.keyedvectors.Vocab at 0x7f0d947ecfd0>,
#  'manager': <gensim.models.keyedvectors.Vocab at 0x7f0d947eceb8>,
#  'jan': <gensim.models.keyedvectors.Vocab at 0x7f0d947ecef0>,
#  'away': <gensim.models.keyedvectors.Vocab at 0x7f0d947ecf28>,
#  "i've": <gensim.models.keyedvectors.Vocab at 0x7f0d947ecbe0>,
#  'receive': <gensim.models.keyedvectors.Vocab at 0x7f0d947ecc50>,
#  'within': <gensim.models.keyedvectors.Vocab at 0x7f0d947ecc88>,
#  'credit': <gensim.models.keyedvectors.Vocab at 0x7f0d947eccf8>,
#  "i'm": <gensim.models.keyedvectors.Vocab at 0x7f0d947ecd30>,
#  'yet': <gensim.models.keyedvectors.Vocab at 0x7f0d947ecd68>,
#  'place': <gensim.models.keyedvectors.Vocab at 0x7f0d947ecda0>,
#  'address': <gensim.models.keyedvectors.Vocab at 0x7f0d947ece10>,
#  'noise': <gensim.models.keyedvectors.Vocab at 0x7f0d947ece48>,
#  'october': <gensim.models.keyedvectors.Vocab at 0x7f0d947ece80>,
#  'december': <gensim.models.keyedvectors.Vocab at 0x7f0d947ec080>,
#  'rep': <gensim.models.keyedvectors.Vocab at 0x7f0d947ec0b8>,
#  'window': <gensim.models.keyedvectors.Vocab at 0x7f0d947ec0f0>,
#  'top': <gensim.models.keyedvectors.Vocab at 0x7f0d947ec160>,
#  'door': <gensim.models.keyedvectors.Vocab at 0x7f0d947ec198>,
#  'ship': <gensim.models.keyedvectors.Vocab at 0x7f0d947ec240>,
#  'control': <gensim.models.keyedvectors.Vocab at 0x7f0d947ec208>,
#  'family': <gensim.models.keyedvectors.Vocab at 0x7f0d947ec278>,
#  'complaint': <gensim.models.keyedvectors.Vocab at 0x7f0d947ec2b0>,
#  'model': <gensim.models.keyedvectors.Vocab at 0x7f0d947ec320>,
#  'response': <gensim.models.keyedvectors.Vocab at 0x7f0d947ec358>,
#  'price': <gensim.models.keyedvectors.Vocab at 0x7f0d947ec3c8>,
#  'wasn\x83t': <gensim.models.keyedvectors.Vocab at 0x7f0d947ec390>,
#  'follow': <gensim.models.keyedvectors.Vocab at 0x7f0d947ec400>,
#  'furnace': <gensim.models.keyedvectors.Vocab at 0x7f0d947ec438>,
#  'while': <gensim.models.keyedvectors.Vocab at 0x7f0d947ec470>,
#  'figure': <gensim.models.keyedvectors.Vocab at 0x7f0d947ec4a8>,
#  'where': <gensim.models.keyedvectors.Vocab at 0x7f0d947ec4e0>,
#  'start': <gensim.models.keyedvectors.Vocab at 0x7f0d947ec518>,
#  'speak': <gensim.models.keyedvectors.Vocab at 0x7f0d947ec550>,
#  'supervisor': <gensim.models.keyedvectors.Vocab at 0x7f0d947ec588>,
#  'earliest': <gensim.models.keyedvectors.Vocab at 0x7f0d947ec5c0>,
#  'miss': <gensim.models.keyedvectors.Vocab at 0x7f0d947ec5f8>,
#  'maybe': <gensim.models.keyedvectors.Vocab at 0x7f0d947ec630>,
#  'explain': <gensim.models.keyedvectors.Vocab at 0x7f0d947ec668>,
#  'can\x83t': <gensim.models.keyedvectors.Vocab at 0x7f0d947ec6a0>,
#  'hear': <gensim.models.keyedvectors.Vocab at 0x7f0d947ec6d8>,
#  'things': <gensim.models.keyedvectors.Vocab at 0x7f0d947ec748>,
#  'third': <gensim.models.keyedvectors.Vocab at 0x7f0d947ec780>,
#  'original': <gensim.models.keyedvectors.Vocab at 0x7f0d947ec7b8>,
#  'complete': <gensim.models.keyedvectors.Vocab at 0x7f0d947ec828>,
#  'ridiculous': <gensim.models.keyedvectors.Vocab at 0x7f0d947ec860>,
#  'date': <gensim.models.keyedvectors.Vocab at 0x7f0d947ec898>,
#  'dry': <gensim.models.keyedvectors.Vocab at 0x7f0d947ec908>,
#  'information': <gensim.models.keyedvectors.Vocab at 0x7f0d947ec978>,
#  'loose': <gensim.models.keyedvectors.Vocab at 0x7f0d947ec9b0>,
#  'write': <gensim.models.keyedvectors.Vocab at 0x7f0d947ec9e8>,
#  'sell': <gensim.models.keyedvectors.Vocab at 0x7f0d947eca20>,
#  'appt': <gensim.models.keyedvectors.Vocab at 0x7f0d947eca58>,
#  'fridge': <gensim.models.keyedvectors.Vocab at 0x7f0d947eca90>,
#  'cannot': <gensim.models.keyedvectors.Vocab at 0x7f0d947ecac8>,
#  'return': <gensim.models.keyedvectors.Vocab at 0x7f0d947ecb00>,
#  'reach': <gensim.models.keyedvectors.Vocab at 0x7f0d947ecba8>,
#  'unit': <gensim.models.keyedvectors.Vocab at 0x7f0d947f0048>,
#  'defective': <gensim.models.keyedvectors.Vocab at 0x7f0d947f00b8>,
#  'coil': <gensim.models.keyedvectors.Vocab at 0x7f0d947f00f0>,
#  'dollars': <gensim.models.keyedvectors.Vocab at 0x7f0d947f0128>,
#  'cool': <gensim.models.keyedvectors.Vocab at 0x7f0d947f0160>,
#  'filter': <gensim.models.keyedvectors.Vocab at 0x7f0d947f01d0>,
#  'cycle': <gensim.models.keyedvectors.Vocab at 0x7f0d947f0208>,
#  'read': <gensim.models.keyedvectors.Vocab at 0x7f0d947f0240>,
#  'simple': <gensim.models.keyedvectors.Vocab at 0x7f0d947f0278>,
#  'believe': <gensim.models.keyedvectors.Vocab at 0x7f0d947f02b0>,
#  'let': <gensim.models.keyedvectors.Vocab at 0x7f0d947f02e8>,
#  'hole': <gensim.models.keyedvectors.Vocab at 0x7f0d947f0320>,
#  'panel': <gensim.models.keyedvectors.Vocab at 0x7f0d947f0358>,
#  'inside': <gensim.models.keyedvectors.Vocab at 0x7f0d947f0390>,
#  'minute': <gensim.models.keyedvectors.Vocab at 0x7f0d947f03c8>,
#  'department': <gensim.models.keyedvectors.Vocab at 0x7f0d947f0400>,
#  'star': <gensim.models.keyedvectors.Vocab at 0x7f0d947f0438>,
#  'products': <gensim.models.keyedvectors.Vocab at 0x7f0d947f0470>,
#  'wife': <gensim.models.keyedvectors.Vocab at 0x7f0d947f04a8>,
#  'diagnosis': <gensim.models.keyedvectors.Vocab at 0x7f0d947f0518>,
#  'fine': <gensim.models.keyedvectors.Vocab at 0x7f0d947f0550>,
#  'card': <gensim.models.keyedvectors.Vocab at 0x7f0d947f0588>,
#  'sit': <gensim.models.keyedvectors.Vocab at 0x7f0d947f05c0>,
#  'regard': <gensim.models.keyedvectors.Vocab at 0x7f0d947f05f8>,
#  'level': <gensim.models.keyedvectors.Vocab at 0x7f0d947f0630>,
#  'possible': <gensim.models.keyedvectors.Vocab at 0x7f0d947f0668>,
#  'hose': <gensim.models.keyedvectors.Vocab at 0x7f0d947f06a0>,
#  'move': <gensim.models.keyedvectors.Vocab at 0x7f0d947f06d8>,
#  'worth': <gensim.models.keyedvectors.Vocab at 0x7f0d947f0710>,
#  'automate': <gensim.models.keyedvectors.Vocab at 0x7f0d947f0748>,
#  'provide': <gensim.models.keyedvectors.Vocab at 0x7f0d947f0780>,
#  'delay': <gensim.models.keyedvectors.Vocab at 0x7f0d947f07f0>,
#  'overall': <gensim.models.keyedvectors.Vocab at 0x7f0d947f0828>,
#  'far': <gensim.models.keyedvectors.Vocab at 0x7f0d947f0898>,
#  'program': <gensim.models.keyedvectors.Vocab at 0x7f0d947f0908>,
#  'update': <gensim.models.keyedvectors.Vocab at 0x7f0d947f0940>,
#  'icemaker': <gensim.models.keyedvectors.Vocab at 0x7f0d947f0978>,
#  'properly': <gensim.models.keyedvectors.Vocab at 0x7f0d947f09b0>,
#  'kenmore': <gensim.models.keyedvectors.Vocab at 0x7f0d947f09e8>,
#  'st': <gensim.models.keyedvectors.Vocab at 0x7f0d947f0a20>,
#  'enough': <gensim.models.keyedvectors.Vocab at 0x7f0d947f0a58>,
#  'nd': <gensim.models.keyedvectors.Vocab at 0x7f0d947f0a90>,
#  'protection': <gensim.models.keyedvectors.Vocab at 0x7f0d947f0ac8>,
#  'professional': <gensim.models.keyedvectors.Vocab at 0x7f0d947f0b00>,
#  'kitchen': <gensim.models.keyedvectors.Vocab at 0x7f0d947f0b38>,
#  'either': <gensim.models.keyedvectors.Vocab at 0x7f0d947f0b70>,
#  'better': <gensim.models.keyedvectors.Vocab at 0x7f0d947f0ba8>,
#  'sign': <gensim.models.keyedvectors.Vocab at 0x7f0d947f0be0>,
#  'system': <gensim.models.keyedvectors.Vocab at 0x7f0d947f0c18>,
#  'concern': <gensim.models.keyedvectors.Vocab at 0x7f0d947f0c50>,
#  'refuse': <gensim.models.keyedvectors.Vocab at 0x7f0d947f0c88>,
#  'lot': <gensim.models.keyedvectors.Vocab at 0x7f0d947f0cf8>,
#  'deductible': <gensim.models.keyedvectors.Vocab at 0x7f0d947f0d30>,
#  'quote': <gensim.models.keyedvectors.Vocab at 0x7f0d947f0d68>,
#  'confirm': <gensim.models.keyedvectors.Vocab at 0x7f0d947f0da0>,
#  'probably': <gensim.models.keyedvectors.Vocab at 0x7f0d947f0dd8>,
#  'operate': <gensim.models.keyedvectors.Vocab at 0x7f0d947f0e10>,
#  'correctly': <gensim.models.keyedvectors.Vocab at 0x7f0d947f0e80>,
#  'product': <gensim.models.keyedvectors.Vocab at 0x7f0d947f0eb8>,
#  'maker': <gensim.models.keyedvectors.Vocab at 0x7f0d947f0ef0>,
#  'unhappy': <gensim.models.keyedvectors.Vocab at 0x7f0d947f0f28>,
#  'file': <gensim.models.keyedvectors.Vocab at 0x7f0d947f0f60>,
#  'communication': <gensim.models.keyedvectors.Vocab at 0x7f0d947f0f98>,
#  'pull': <gensim.models.keyedvectors.Vocab at 0x7f0d947f0fd0>,
#  'note': <gensim.models.keyedvectors.Vocab at 0x7f0d947eaa90>,
#  'husband': <gensim.models.keyedvectors.Vocab at 0x7f0d947eaac8>,
#  'diagnose': <gensim.models.keyedvectors.Vocab at 0x7f0d947eab00>,
#  'comment': <gensim.models.keyedvectors.Vocab at 0x7f0d947eab38>,
#  'idea': <gensim.models.keyedvectors.Vocab at 0x7f0d947eab70>,
#  'sound': <gensim.models.keyedvectors.Vocab at 0x7f0d947eaba8>,
#  'mess': <gensim.models.keyedvectors.Vocab at 0x7f0d947eabe0>,
#  'future': <gensim.models.keyedvectors.Vocab at 0x7f0d947eac18>,
#  'function': <gensim.models.keyedvectors.Vocab at 0x7f0d947eac50>,
#  'light': <gensim.models.keyedvectors.Vocab at 0x7f0d947eac88>,
#  'apparently': <gensim.models.keyedvectors.Vocab at 0x7f0d947eacc0>,
#  'samsung': <gensim.models.keyedvectors.Vocab at 0x7f0d947ead68>,
#  'hot': <gensim.models.keyedvectors.Vocab at 0x7f0d947eada0>}

# %%
model1.most_similar('repairman')  # Checking all the words similar to repairman
# Out:
# /home/bmalli1/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('return', 0.38222774863243103),
#  ('representative', 0.38058820366859436),
#  ('situation', 0.3534719944000244),
#  ('heater', 0.34667131304740906),
#  ('report', 0.34176570177078247),
#  ('instal', 0.3282763361930847),
#  ('enough', 0.3186523914337158),
#  ('&', 0.3119112253189087),
#  ('finally', 0.30898115038871765),
#  ('horrible', 0.2751517593860626)]

# %%
model1['repairman']
# Out:
# /home/bmalli1/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """Entry point for launching an IPython kernel.
# array([ 1.6827319 , -0.53736347, -0.4222089 ,  1.8111184 ,  0.5805491 ,
#        -0.53974885,  1.0798132 , -0.51003444, -0.6268802 , -2.4994645 ,
#        -3.2260056 ,  1.9444085 ,  0.47631308,  0.39567935,  1.2158549 ,
#        -1.0989057 , -0.5542868 ,  0.0828223 ,  0.5541401 , -1.4545407 ,
#         1.6008999 ,  0.951255  , -0.53193015, -0.9689449 , -0.28741553,
#        -1.3887663 , -0.33563244, -0.7965994 , -0.28676262,  1.1787198 ,
#        -0.94548726,  1.1061553 , -0.9657425 ,  0.51316065,  1.8412879 ,
#        -0.01422593,  0.5889897 ,  1.0532249 , -0.44548166,  0.12657626,
#        -0.03266321, -0.61646193,  0.6188718 , -0.6116894 , -0.8054796 ,
#        -0.13376845, -0.26679343, -0.58641165,  0.44420508, -0.69058216,
#         0.3834735 ,  0.2798166 ,  1.2926862 ,  0.58021736, -0.9665022 ,
#         1.1386018 ,  0.48485073,  0.5862532 ,  0.30891368, -0.6403976 ,
#         0.7439217 ,  0.32564458, -1.5680337 ,  0.68737924,  0.16987216,
#        -3.3778696 , -2.25833   ,  2.0282166 , -1.4312823 ,  0.73341477,
#         1.193959  ,  0.73992217, -0.10740955, -0.03911191, -1.1822503 ,
#         1.3965069 ,  0.6875415 ,  0.5580193 , -1.5874662 ,  0.30124277,
#         0.1455745 , -0.3912387 ,  0.6048758 ,  0.08712762,  0.02682187,
#         0.07825547, -0.5960572 , -0.3780256 , -0.03657321,  0.40338343,
#        -0.725194  , -0.6648847 , -0.6113149 , -0.3025991 ,  0.4252779 ,
#        -0.08180172,  0.1966352 ,  0.43655387,  0.46736062, -1.7848171 ,
#        -0.7491616 , -0.51121277, -0.4893518 ,  0.6499589 ,  0.0253615 ,
#        -0.06636646,  1.1347287 , -0.91987425, -0.9624228 ,  0.21001326,
#         1.0693046 , -2.0165157 ,  0.01277626, -0.9287337 , -0.4680637 ,
#         0.05578334, -0.1970038 ,  0.4571788 ,  0.44830236, -0.2767446 ,
#        -0.1138449 ,  0.27927294,  0.84294695,  0.7237453 , -0.26788238,
#         0.71863043, -0.05371676,  0.50332016,  1.0375922 ,  0.80136734,
#         0.06847198,  1.0302432 , -0.9160861 , -0.60945314,  0.51140094,
#        -0.46815842,  0.06765598,  1.5916967 ,  0.11459947,  1.5896251 ,
#        -0.07085148,  0.18585818,  0.30758768, -1.1197501 ,  1.1139243 ,
#        -1.6212486 , -0.02872621, -0.44948336, -1.3720974 ,  0.7073941 ,
#        -0.8306268 ,  1.0498255 ,  0.45805955,  0.33104706,  1.073651  ,
#         0.34134787,  0.93728626,  1.335531  ,  0.6456927 ,  0.39505786,
#        -0.3001974 , -0.9055345 , -0.64822644,  0.61707234,  0.1558139 ,
#         0.3979783 , -0.00059089, -0.60024333,  0.1026432 ,  0.44011143,
#        -0.19623527,  0.08722109,  0.02248408, -0.2631019 ,  0.1505598 ,
#         0.00055924, -1.6131972 , -0.62640554, -0.24101864,  2.0652516 ,
#         0.11696091, -1.2478541 ,  0.44455552,  0.17044449,  0.07439113,
#         2.079447  ,  0.5460176 , -1.1778463 , -0.37610823, -0.07172973,
#         1.1675445 ,  0.12480018, -0.7028586 , -0.03185606, -0.9552051 ,
#         0.2120686 , -1.0552669 , -1.2629114 , -1.3421725 , -0.44401738,
#         0.9559508 ,  1.3204658 , -0.23363392, -1.7582415 ,  0.6420415 ,
#        -0.52962196,  0.5510669 , -1.8056349 ,  0.4668673 , -0.6580216 ,
#        -0.5245041 ,  0.75434405, -0.49054343,  1.2456313 , -1.0811436 ,
#         0.1338627 ,  1.3622396 ,  0.29553825,  1.0106062 ,  0.5895158 ,
#        -0.38036633, -0.9967099 , -0.5848511 , -1.7048925 ,  1.3647616 ,
#        -1.0039334 ,  0.26465848,  0.3785823 , -0.21797915,  0.4931654 ,
#        -0.5518545 , -0.4913835 ,  0.1141523 ,  1.5777466 ,  1.4127009 ,
#        -0.8098621 ,  1.262492  ,  0.08448905, -0.77384746,  0.92093724,
#         2.046485  ,  0.08618087, -0.12750001,  0.8972849 ,  0.3398261 ,
#        -0.03024325,  0.27107045,  0.7376345 , -0.15921079, -0.5873091 ,
#         0.38730937, -0.43982595,  0.5042122 , -1.6972154 ,  0.9039631 ,
#        -0.85422075,  0.37387845,  1.0797429 ,  2.6562936 ,  1.8917428 ,
#        -1.1333138 ,  0.28844544,  0.4318045 ,  0.08680666,  0.81651175,
#        -1.2983339 , -0.9892233 , -1.1465154 , -1.7996883 ,  0.8796836 ,
#        -2.3278415 ,  0.3946786 ,  1.0656978 ,  0.6143163 , -0.21780582,
#        -0.35627517, -1.0155014 ,  1.0913166 ,  0.0068794 ,  0.30319282,
#         0.07616504,  0.41281644, -0.5585034 , -0.91914254,  1.1284767 ,
#        -0.15148278,  0.5111321 , -0.13066472,  0.23942673, -0.4733185 ,
#         1.5328609 ,  0.7635117 , -1.2556942 ,  0.64689034,  0.56170493,
#        -0.19405793,  0.8558189 ,  0.98656505, -4.5371943 , -0.09727173],
#       dtype=float32)

# %% [markdown]
# Now we will write a function to build word vectors from the embeddings we got from Word2Vec

# %%
def buildWordVector(tokens, size):
    vec = np.zeros(size).reshape((1, size))
    count = 0.
    for word in tokens:
        try:
            vec += model1[word].reshape((1, size))  
            count += 1.
        except KeyError: # handling the case where the token is not
                         # in the corpus. useful for testing.
            continue
    return vec

# %% [markdown]
# Now we convert x_train and and x_test into list of vectors using labelizeFeedbacks function. <br />
# We also scale each column to have zero mean and unit standard deviation.

# %%
from sklearn.preprocessing import scale 
n_dim = input_size
# To create vector corresponding to each feedback

train_vecs_w2v = np.concatenate([buildWordVector(z, n_dim) for z in tqdm(map(lambda x: x.words, x_train))])
#train_vecs_w2v = scale(train_vecs_w2v) # if we want to scale

test_vecs_w2v =  np.concatenate([buildWordVector(z, n_dim) for z in tqdm(map(lambda x: x.words, x_test))])
#test_vecs_w2v = scale(test_vecs_w2v)  # if we want to scale
# Out:
# 0it [00:00, ?it/s]/home/bmalli1/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# 499it [00:00, 5069.60it/s]
# 499it [00:00, 5574.81it/s]

# %%
print(train_vecs_w2v.shape)
print(test_vecs_w2v.shape)
# Out:
# (499, 300)
# (499, 300)

# %%
# One-hot encoding of the target 
Y_train = pd.get_dummies(Y_train).values

# %%
Y_train.shape
# Out:
# (499, 12)

# %%
model = Sequential()
model.add(Dense(196,activation='tanh',input_dim=input_size, kernel_initializer='random_uniform')) # random_uniform
model.add(Dense(12, activation='softmax'))
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])
print(model.summary())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_7 (Dense)              (None, 196)               58996
# _________________________________________________________________
# dense_8 (Dense)              (None, 12)                2364
# =================================================================
# Total params: 61,360
# Trainable params: 61,360
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
model.fit(train_vecs_w2v, Y_train, epochs=20, batch_size=196, verbose=2) #, class_weight = 'auto')
# Out:
# Epoch 1/20
#  - 0s - loss: 2.6364 - acc: 0.1623
# Epoch 2/20
#  - 0s - loss: 1.8475 - acc: 0.3848
# Epoch 3/20
#  - 0s - loss: 1.4503 - acc: 0.5371
# Epoch 4/20
#  - 0s - loss: 1.2358 - acc: 0.5972
# Epoch 5/20
#  - 0s - loss: 1.0961 - acc: 0.6613
# Epoch 6/20
#  - 0s - loss: 0.9710 - acc: 0.7074
# Epoch 7/20
#  - 0s - loss: 0.8643 - acc: 0.7635
# Epoch 8/20
#  - 0s - loss: 0.7910 - acc: 0.7836
# Epoch 9/20
#  - 0s - loss: 0.7157 - acc: 0.8096
# Epoch 10/20
#  - 0s - loss: 0.6500 - acc: 0.8477
# Epoch 11/20
#  - 0s - loss: 0.5988 - acc: 0.8717
# Epoch 12/20
#  - 0s - loss: 0.5505 - acc: 0.8938
# Epoch 13/20
#  - 0s - loss: 0.5102 - acc: 0.9018
# Epoch 14/20
#  - 0s - loss: 0.4737 - acc: 0.9178
# Epoch 15/20
#  - 0s - loss: 0.4391 - acc: 0.9339
# Epoch 16/20
#  - 0s - loss: 0.4087 - acc: 0.9479
# Epoch 17/20
#  - 0s - loss: 0.3818 - acc: 0.9479
# Epoch 18/20
#  - 0s - loss: 0.3582 - acc: 0.9599
# Epoch 19/20
#  - 0s - loss: 0.3360 - acc: 0.9679
# Epoch 20/20
#  - 0s - loss: 0.3157 - acc: 0.9679

# %% [markdown]
# Now we save the prediction on our test data

# %%
out_ = model.predict_classes(test_vecs_w2v)
out_put = le.inverse_transform(out_)
np.set_printoptions(suppress=True)
prob = model.predict_proba(test_vecs_w2v)

# %% [markdown]
# This is the calculation of probability score of each feedbacks.
# We will predict top 3 Themes for each feedback based on their probability score we got from the model

# %%
a = np.argmax(prob,axis=1)
p = prob.max(axis=1)
label_1 = le.inverse_transform(a)

for i in range(test_vecs_w2v.shape[0]):
    prob[i,a[i]] = -1
    
b = np.argmax(prob,axis=1)
q = prob.max(axis=1)
label_2 = le.inverse_transform(b)

for i in range(test_vecs_w2v.shape[0]):
    prob[i,b[i]] = -1

c = np.argmax(prob,axis=1)
r = prob.max(axis=1)
label_3 = le.inverse_transform(c)

labels=np.column_stack((label_1,label_2,label_3))
probabilities=np.column_stack((p,q,r))

# %%
output= np.column_stack((df.feedback[499:],labels,probabilities))

# %%
output = pd.DataFrame(output)

# %%
output.columns =['Feedback','Theme_1','Theme_2','Theme_3','prob_Theme_1','prob_Theme_2','prob_Theme_3']

# %%
output
# Out:
#                                               Feedback  \
# 0    I get a bit frustrated , when I ha e to spend ...
# 1    I called the morning of appt. and they said th...
# 2    Tech was rude and cursed my family. Did not sp...
# 3    I ordered my dish washer fixed.  Your computer...
# 4    additional service visit required to address i...
# 5    The technician from A&E called at 8:45 today f...
# 6                            Call me at (989) 839 0436
# 7    Tech '  sass.   All of them ordered parts for ...
# 8    Fifth visit now and 2 hours after the tech lef...
# 9    Tom was not helpful in solving the problem. Af...
# 10   the repair people were good, however I am trap...
# 11   Tech did not complete requested services. Ther...
# 12   On the previous visit, the tech said it was a ...
# 13   Tech arrived about 20 minutes late when he had...
# 14                 Never received call tech was coming
# 15   I made the appointment and said I needed oven ...
# 16   Case 4200331 My fridge is still broken from OC...
# 17   Poor communication within the Sears warranty s...
# 18   You misrepresented your fees. I will never use...
# 19   Sears has a serious ongoing problem--untrained...
# 20   Was on hold with the 800-4-MY-HOME for more th...
# 21   I have been without a washing machine since No...
# 22   Technician said did not have the replacement p...
# 23   Repai guy was awsome. Sears was not. It took t...
# 24                             Has not been completed.
# 25   Did not receive email or text messages that te...
# 26   I have had the same parts replaced replaced an...
# 27   I am not happy with the service I received. A ...
# 28                                      Lazy lazy lazy
# 29   I was given a 4-Hour window. From 1 p.m. to 5 ...
# ..                                                 ...
# 469  Tech replaced failed part.  New part makes sam...
# 470  First tech evaluated the problem. Second tech ...
# 471  the rubber was replaced on my fridge/freezer i...
# 472  Tech's are great your customer service not so ...
# 473  Your scheduling system is the worst.  Especial...
# 474  Tech installed new compressor. Compressor does...
# 475  The heating element keeps warping.  All they d...
# 476  The tech that did arrive was great! I gave onl...
# 477  Did not show up . Need to schedule another app...
# 478  2nd visit after parts were ordered. Tech asked...
# 479  I??m very disappointed , today is December 29...
# 480  12 days for repair man to arrive. To arrive be...
# 481  My issue is not with the technician but the ov...
# 482  Tech expertise was excellent, but he left my h...
# 483   The technician looked at the grill and left w...
# 484  The tech was great. The policy of charging $79...
# 485  Did not fix problem (though he did, honestly, ...
# 486  Repair did not last even one snow fall. No sno...
# 487  The repair was fine but the first time it was ...
# 488  the technician was not the problem. It was abs...
# 489  Technician did not know how to use the credit ...
# 490  Tech who repairs my tractor, Doug, is always g...
# 491  I now have a broken machine when the technicia...
# 492  Wrong part was ordered and resulted in a huge ...
# 493                    Had to wait two weeks for parts
# 494  I have had this problem from the day I first u...
# 495  The tech #0799288 refused to test the machine ...
# 496  Tech #0897538 was disrespectful and talked dow...
# 497  No one ever showed up. No phone call or email....
# 498  Called 3x after visit was completed and was hu...
#
#                                                Theme_1  \
# 0             Technician not having required expertise
# 1            Scheduling issue (Call center experience)
# 2                   Repaired product still not working
# 3    Dissatisfied with service provided even after ...
# 4    Dissatisfied with service provided even after ...
# 5    Technician not turning up at all or on schedul...
# 6            Scheduling issue (Call center experience)
# 7                   Repaired product still not working
# 8    Technician not turning up at all or on schedul...
# 9                   Repaired product still not working
# 10           Scheduling issue (Call center experience)
# 11   Technician code of conduct\n(Didn't inspected ...
# 12           Scheduling issue (Call center experience)
# 13   Technician not turning up at all or on schedul...
# 14   Technician not turning up at all or on schedul...
# 15           Scheduling issue (Call center experience)
# 16                                              Others
# 17              Extremely dissatisifed with experience
# 18              Extremely dissatisifed with experience
# 19   Technician not turning up at all or on schedul...
# 20           Scheduling issue (Call center experience)
# 21   Dissatisfied with service provided even after ...
# 22                  Repaired product still not working
# 23                                              Others
# 24                                              Others
# 25   Technician not turning up at all or on schedul...
# 26                  Repaired product still not working
# 27           Scheduling issue (Call center experience)
# 28                                              Others
# 29   Technician not turning up at all or on schedul...
# ..                                                 ...
# 469       Parts unavailability or Wrong Part delivered
# 470  Dissatisfied with service provided even after ...
# 471  Technician code of conduct\n(Didn't inspected ...
# 472             Extremely dissatisifed with experience
# 473          Scheduling issue (Call center experience)
# 474           Technician not having required expertise
# 475             Extremely dissatisifed with experience
# 476          Scheduling issue (Call center experience)
# 477  Technician not turning up at all or on schedul...
# 478       Parts unavailability or Wrong Part delivered
# 479                 Repaired product still not working
# 480          Scheduling issue (Call center experience)
# 481          Scheduling issue (Call center experience)
# 482           Technician not having required expertise
# 483  Technician not turning up at all or on schedul...
# 484                     Service charges are too costly
# 485           Technician not having required expertise
# 486                                             Others
# 487  Technician not turning up at all or on schedul...
# 488          Scheduling issue (Call center experience)
# 489          Scheduling issue (Call center experience)
# 490          Scheduling issue (Call center experience)
# 491                 Repaired product still not working
# 492       Parts unavailability or Wrong Part delivered
# 493       Parts unavailability or Wrong Part delivered
# 494                                             Others
# 495  Technician code of conduct\n(Didn't inspected ...
# 496  Technician code of conduct\n(Didn't inspected ...
# 497          Scheduling issue (Call center experience)
# 498          Scheduling issue (Call center experience)
#
#                                                Theme_2  \
# 0         Parts unavailability or Wrong Part delivered
# 1    Technician not turning up at all or on schedul...
# 2    Technician code of conduct\n(Didn't inspected ...
# 3               Extremely dissatisifed with experience
# 4            Scheduling issue (Call center experience)
# 5            Scheduling issue (Call center experience)
# 6    Technician not turning up at all or on schedul...
# 7         Parts unavailability or Wrong Part delivered
# 8                                               Others
# 9             Technician not having required expertise
# 10   Dissatisfied with service provided even after ...
# 11            Technician not having required expertise
# 12   Dissatisfied with service provided even after ...
# 13   Technician code of conduct\n(Didn't inspected ...
# 14           Scheduling issue (Call center experience)
# 15            Technician not having required expertise
# 16                  Repaired product still not working
# 17                                              Others
# 18                      Service charges are too costly
# 19           Scheduling issue (Call center experience)
# 20   Technician not turning up at all or on schedul...
# 21            Technician not having required expertise
# 22   Dissatisfied with service provided even after ...
# 23   Dissatisfied with service provided even after ...
# 24   Dissatisfied with service provided even after ...
# 25           Scheduling issue (Call center experience)
# 26        Parts unavailability or Wrong Part delivered
# 27   Dissatisfied with service provided even after ...
# 28                  Repaired product still not working
# 29           Scheduling issue (Call center experience)
# ..                                                 ...
# 469           Technician not having required expertise
# 470           Technician not having required expertise
# 471           Technician not having required expertise
# 472  Dissatisfied with service provided even after ...
# 473  Technician not turning up at all or on schedul...
# 474  Technician not turning up at all or on schedul...
# 475                                             Others
# 476  Technician not turning up at all or on schedul...
# 477          Scheduling issue (Call center experience)
# 478           Technician not having required expertise
# 479           Technician not having required expertise
# 480  Technician not turning up at all or on schedul...
# 481  Technician not turning up at all or on schedul...
# 482               Request for contact back by customer
# 483                 Repaired product still not working
# 484    Dissatisfied with warranty terms and conditions
# 485  Technician not turning up at all or on schedul...
# 486                 Repaired product still not working
# 487          Scheduling issue (Call center experience)
# 488               Request for contact back by customer
# 489             Extremely dissatisifed with experience
# 490       Parts unavailability or Wrong Part delivered
# 491  Dissatisfied with service provided even after ...
# 492  Dissatisfied with service provided even after ...
# 493  Dissatisfied with service provided even after ...
# 494             Extremely dissatisifed with experience
# 495           Technician not having required expertise
# 496                 Repaired product still not working
# 497  Technician not turning up at all or on schedul...
# 498  Technician not turning up at all or on schedul...
#
#                                                Theme_3 prob_Theme_1  \
# 0            Scheduling issue (Call center experience)     0.420471
# 1    Technician code of conduct\n(Didn't inspected ...     0.739004
# 2             Technician not having required expertise      0.38967
# 3            Scheduling issue (Call center experience)      0.23868
# 4      Dissatisfied with warranty terms and conditions     0.396233
# 5               Extremely dissatisifed with experience     0.585341
# 6                       Service charges are too costly     0.296956
# 7             Technician not having required expertise     0.362215
# 8            Scheduling issue (Call center experience)     0.959888
# 9                                               Others     0.496128
# 10              Extremely dissatisifed with experience     0.679608
# 11   Technician not turning up at all or on schedul...     0.651413
# 12        Parts unavailability or Wrong Part delivered     0.706293
# 13            Technician not having required expertise     0.670557
# 14                      Service charges are too costly      0.74152
# 15   Dissatisfied with service provided even after ...     0.207329
# 16           Scheduling issue (Call center experience)     0.458154
# 17     Dissatisfied with warranty terms and conditions     0.365959
# 18                                              Others     0.882511
# 19                Request for contact back by customer     0.475372
# 20                                              Others     0.569312
# 21                  Repaired product still not working     0.650154
# 22        Parts unavailability or Wrong Part delivered     0.238134
# 23           Scheduling issue (Call center experience)     0.556853
# 24                  Repaired product still not working     0.534732
# 25                      Service charges are too costly     0.901846
# 26                Request for contact back by customer      0.48177
# 27        Parts unavailability or Wrong Part delivered     0.265928
# 28              Extremely dissatisifed with experience     0.112421
# 29              Extremely dissatisifed with experience     0.996584
# ..                                                 ...          ...
# 469                 Repaired product still not working     0.465874
# 470       Parts unavailability or Wrong Part delivered     0.343067
# 471                 Repaired product still not working     0.529858
# 472                                             Others     0.776394
# 473               Request for contact back by customer     0.871194
# 474                 Repaired product still not working     0.301122
# 475  Technician not turning up at all or on schedul...     0.712764
# 476  Dissatisfied with service provided even after ...     0.545931
# 477  Technician code of conduct\n(Didn't inspected ...     0.535298
# 478  Dissatisfied with service provided even after ...      0.56346
# 479  Dissatisfied with service provided even after ...     0.860056
# 480                                             Others     0.396665
# 481                                             Others     0.954035
# 482          Scheduling issue (Call center experience)     0.365723
# 483             Extremely dissatisifed with experience     0.514974
# 484           Technician not having required expertise     0.545181
# 485                 Repaired product still not working     0.795141
# 486  Dissatisfied with service provided even after ...     0.379302
# 487                                             Others      0.98865
# 488                                             Others     0.724957
# 489  Dissatisfied with service provided even after ...     0.450026
# 490  Dissatisfied with service provided even after ...     0.510373
# 491                                             Others     0.544565
# 492           Technician not having required expertise     0.671373
# 493             Extremely dissatisifed with experience     0.888784
# 494  Dissatisfied with service provided even after ...     0.410643
# 495                 Repaired product still not working     0.957001
# 496             Extremely dissatisifed with experience     0.651188
# 497                                             Others      0.47772
# 498  Dissatisfied with service provided even after ...     0.975492
#
#     prob_Theme_2 prob_Theme_3
# 0       0.178976     0.149998
# 1       0.195259    0.0160344
# 2       0.347107     0.171259
# 3       0.218975     0.176128
# 4       0.130867     0.107617
# 5       0.377898    0.0111576
# 6       0.260585     0.133381
# 7       0.308458     0.245629
# 8      0.0127786   0.00879363
# 9       0.170389     0.140685
# 10      0.110546    0.0815027
# 11      0.335552   0.00518363
# 12      0.191387     0.055907
# 13      0.278355    0.0326556
# 14         0.124    0.0672596
# 15      0.185579      0.13383
# 16      0.177694     0.153102
# 17       0.21879     0.161113
# 18     0.0392386    0.0184244
# 19      0.435039     0.059635
# 20      0.196438     0.166532
# 21      0.156522    0.0724113
# 22      0.207945     0.158006
# 23      0.182672     0.095958
# 24     0.0991823    0.0654219
# 25     0.0630264    0.0214558
# 26       0.39309    0.0338504
# 27       0.22786     0.166725
# 28      0.108511    0.0899472
# 29    0.00193368   0.00064284
# ..           ...          ...
# 469      0.15243     0.102825
# 470     0.321694     0.163354
# 471     0.268323     0.127022
# 472    0.0950286    0.0815683
# 473    0.0761693    0.0201514
# 474     0.187642     0.150258
# 475     0.230004    0.0328425
# 476     0.386918    0.0228263
# 477     0.407216    0.0180641
# 478     0.174924    0.0839785
# 479    0.0424303    0.0376843
# 480     0.360075    0.0769654
# 481    0.0351796    0.0031494
# 482     0.180611     0.169478
# 483     0.256808    0.0796224
# 484     0.280093    0.0500965
# 485    0.0877475    0.0589625
# 486     0.253628     0.156618
# 487   0.00871266  0.000935745
# 488     0.129475    0.0521969
# 489     0.342323     0.100204
# 490     0.438969    0.0259388
# 491     0.320149    0.0737064
# 492     0.152293    0.0545871
# 493    0.0523936    0.0146421
# 494     0.380792    0.0618545
# 495    0.0275518    0.0109868
# 496     0.185788    0.0516653
# 497     0.262513     0.134327
# 498   0.00571006   0.00454086
#
# [499 rows x 7 columns]
